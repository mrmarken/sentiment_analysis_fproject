# %% [markdown]
# # Fetching Tweets for Big Dataset (70K+ Tweets) from Twitter API

# %% [markdown]
# ## Twitter API Premium v1.1: Search Tweets 30-Day Endpoint

# %%
# Import dependencies
import tweepy
import pandas as pd
import numpy as np
import json
import time
from datetime import datetime
import addfips

# %%
# Import API client token
import os
from dotenv import load_dotenv
load_dotenv()

twit_token = os.getenv('twit_token')

# %%
# Set up API authorization
auth = tweepy.OAuth2BearerHandler(twit_token)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
# Code reproduced from Twitter developer API documentation. Additional parsing features and customizations made where necessary for desired output.
def determine_tweet_type(tweet):
    # Check for reply indicator first
    if tweet["in_reply_to_status_id"] is not None:
        tweet_type = "Reply Tweet"
    # Check boolean quote status field but make sure it's not a Retweet (of a Quote Tweet) 
    elif tweet["is_quote_status"] is True and not tweet["text"].startswith("RT"):
        tweet_type = "Quote Tweet"
    # Check both indicators of a Retweet
    elif tweet["text"].startswith("RT") and tweet.get("retweeted_status") is not None:
        tweet_type = "Retweet"
    else:
        tweet_type = "Original Tweet"
    return tweet_type

parsedTweets = []
daily_parsedTweets = []
rawTweets = []
daily_rawTweets = []

def parse_tweets(status):
    for tweet in status:
        
        rawTweets.append(tweet._json)
        daily_rawTweets.append(tweet._json)
        hashtags = []
        mentions = []
        

        if 'extended_tweet' in tweet._json:
            full_text = tweet._json['extended_tweet']['full_text']

            # Collect hashtags from tweet into list
            hashtags_entity = tweet._json["extended_tweet"]["entities"]["hashtags"]
            if len(hashtags_entity) == 0:
                hashtags = None
            else:
                for hashtag in hashtags_entity:
                    hashtags.append("#" + hashtag['text'])

            # Collect mentions from tweet into list
            mentions_entity = tweet._json["extended_tweet"]["entities"]["user_mentions"]
            if len(mentions_entity) == 0:
                mentions = None
            else:
                for mention in mentions_entity:
                    mentions.append("@" + mention["screen_name"])

        else:
            full_text = tweet._json['text']

            # Collect hashtags from tweet into list
            hashtags_entity = tweet._json["entities"]["hashtags"]
            if len(hashtags_entity) == 0:
                hashtags = None
            else:
                for hashtag in hashtags_entity:
                    hashtags.append("#" + hashtag['text'])

            # Collect mentions from tweet into list
            mentions_entity = tweet._json["entities"]["user_mentions"]
            if len(mentions_entity) == 0:
                mentions = None
            else:
                for mention in mentions_entity:
                    mentions.append("@" + mention["screen_name"])
        
                
        # Get coordinates latitude and longitude into separate variables by subscripting coordinates if coordinates object not Nonetype
        coordinates = tweet._json["coordinates"]
        if coordinates is not None:
            coord_lat = tweet._json["coordinates"]["coordinates"][0]
            coord_lng = tweet._json["coordinates"]["coordinates"][1]
        else:
            coord_lat = None
            coord_lng = None
            
        
        # Get place attributes into separate variables by subscripting place if place object not Nonetype 
        place = tweet._json["place"]
        if place is not None:
            place_type = tweet._json["place"]["place_type"]
            place_name = tweet._json["place"]["name"]
            place_full_name = tweet._json["place"]["full_name"]
            country_code = tweet._json["place"]["country_code"]
            country = tweet._json["place"]["country"]
        else:
            place_type = None
            place_name = None
            place_full_name = None
            country_code = None
            country = None
            
        # Parsing profile geo data

        # First intialize profile geo field values as Nonetype for the default value (value if field not found in profile geo data)
        prof_country = None
        prof_country_code = None
        prof_locality = None
        prof_region = None
        prof_sub_region = None
        prof_full_name = None
        prof_coord_lat = None
        prof_coord_lng = None 

        # Parse desired profile geo data if the field is present 
        for field in tweet._json["user"]: 
            if field == "derived":
                prof_geo_data = tweet._json["user"]["derived"]
                if prof_geo_data["locations"] is not None:
                    for field in prof_geo_data["locations"][0]:
                        if field == "country":
                            prof_country = prof_geo_data["locations"][0][field]

                        elif field == "country_code":
                            prof_country_code = prof_geo_data["locations"][0][field]

                        elif field == "locality":
                            prof_locality = prof_geo_data["locations"][0][field]

                        elif field == "region":
                            prof_region = prof_geo_data["locations"][0][field]

                        elif field == "sub_region":
                            prof_sub_region = prof_geo_data["locations"][0][field]

                        elif field == "full_name":
                            prof_full_name = prof_geo_data["locations"][0][field]

                        elif field == "geo":
                            prof_coord_lat = prof_geo_data["locations"][0][field]["coordinates"][0]
                            prof_coord_lng = prof_geo_data["locations"][0][field]["coordinates"][1]

                        else:
                            pass
                else:
                    pass
            else:
                pass
            

            
        # Create dict with key-value pairs of parsed field and corresponding data
        mydict = { "tweet_id": tweet._json["id_str"], #Tweet ID
                       "date":tweet._json["created_at"], #Timestamp of tweet creation
                       "full_text": full_text, #Full tweet text
                       "tweet_type": determine_tweet_type(tweet._json), #Type of tweet
                       "hashtags": hashtags, #List of hashtags used in the tweet
                       "mentions": mentions, #List of mentions used in the tweet
                       "user_id": tweet._json["user"]["id_str"], #Twitter user profile ID
                       "user_location": tweet._json["user"]["location"], #The user's listed location
                       "geo": tweet._json["geo"], #Geodata 'geo' attribute
                       "lat_coordinates": coord_lat, #Geodata 'latitude coordinates' from 'coordinates' attribute
                       "lng_coordinates": coord_lng, #Geodata 'longitude coordinates' from 'coordinates' attribute
                       "place_type": place_type, #Geodata 'place_type' from 'place' attribute
                       "place_name": place_name, #Geodata 'name' from 'place' attribute
                       "place_full_name": place_full_name, #Geodata 'full_name' from 'place' attribute
                       "country_code": country_code, #Geodata 'country_code' from 'place' attribute
                       "country": country, #Geodata 'country' from 'place' attribute
                       "prof_country": prof_country, #Profile geodata 'country' from 'user''derived''locations'
                       "prof_country_code": prof_country_code, #Profile geodata 'country_code' from 'user''derived''locations'
                       "prof_locality": prof_locality, #Profile geodata 'locality' from 'user''derived''locations'
                       "prof_region": prof_region, #Profile geodata 'region' from 'user''derived''locations'
                       "prof_sub_region": prof_sub_region, #Profile geodata 'sub_region' from 'user''derived''locations'
                       "prof_full_name": prof_full_name, #Profile geodata 'full_name' from 'user''derived''locations'
                       "prof_coord_lat": prof_coord_lat, #Profile geodata 'latitude' from 'user''derived''locations''geo''coordinates'
                       "prof_coord_lng": prof_coord_lng, #Profile geodata 'longitude' from 'user''derived''locations''geo''coordinates'
                       "reply_count": tweet._json["reply_count"], #Number of times Tweet has been replied to
                       "quote_count": tweet._json["quote_count"], # Number of times Tweet has been quoted
                       "likes_count": tweet._json["favorite_count"], #Number of times Tweet has been liked 
                       "retweet_counts": tweet._json["retweet_count"], #Number of times this Tweet has been retweeted
                       "hyperlink": "https://twitter.com/twitter/status/" + tweet._json["id_str"] #Link to tweet
              }
        
        # Append parsed tweet data to list
        parsedTweets.append(mydict) # Add Tweet to parsedTweets list
        
        # Append daily parsed tweet data to daily list
        daily_parsedTweets.append(mydict)

# %%
# Code to run query against the Twitter API v1.1 Premium - 30 day search endpoint for fetching tweets in the last 30-day archive 

query = '(#guncontrol OR #gunrights OR #gunsense OR #2a OR #gunviolence OR #nra OR #guns OR #shooting OR #firearms OR #gunsafety OR #uvalde \
OR "gun control" OR "2nd amendment" OR ("gun" "violence") OR "right to bear" OR "nra" OR ("gun" "safety") OR ("gun" "rights") \
OR "good guy with a gun" OR "assault weapons" OR ("ban" "guns") OR "ban assault" OR ("school" "shootings") OR "ar-15" OR "mass shootings" \
OR "open carry" OR "gun owners" OR "concealed carry" OR "gun laws" OR "gun law" OR "pro-gun" OR "anti-gun" OR "gun safety" OR "high capacity magazine" \
OR "second amendment" OR "gun lobby" OR "gun ownership" OR "carry permit" OR "bump stock" OR "gunman" OR "red flag laws" OR "red-flag laws" OR "brady law" \
OR "gun sales" OR ("buying" ("gun" OR "guns")) OR "gun shows" OR "gun sense" OR "sandy hook" OR ("guns" ("republicans" OR "democrats")) OR (("background check" OR "background checks") \
("gun" OR "guns" OR "sale" OR "sales")) OR (("legal" OR "illegal") ("gun" OR "guns"))) lang:en profile_country:US -is:retweet -is:quote'


# Initalize lists to populate with raw and parsed using parsing function
rawTweets = []
parsedTweets = []
from_date = 1103
to_date = 1104
date_range = range(11)

# Fetch tweets from the endpoint using pagination to collect up to 18,500 tweets for each specified day (UTC)
for date in date_range:
    
    # Parsed tweets for the day
    daily_parsedTweets = []
    daily_rawTweets = []
    
    # Print message for start time of fetching tweets
    print("Fetching Day " + str(date + 1) + " Tweets Start Time : %s" % time.ctime())
    print(f"Fetching Tweets for Day {date + 1} ...\n")
    
    status = tweepy.Cursor(api.search_30_day, label='gunsentiment', query=query, fromDate=f'2022{from_date}0000', toDate=f'2022{to_date}0000', maxResults='500').items(13750)
    
    
    # parse the fetched tweet and store key-value pairs in list of dictionaries in parsedTweets. Append raw JSON responses to rawTweets list
    parse_tweets(status)
    
    # Print message for end time of fetching and parsing tweets
    print(f"Fetched and Parsed All Tweets for Day {date + 1}.")
    print("Fetching and Parsing Day " + str(date + 1) + " Tweets End Time : %s" % time.ctime() + "\n")
    
    # File path name for date
    file_path = f"../res/tweets_per_day/{from_date}2022_tweets"
    
    # Read daily parsed tweets into a dataframe
    daily_parsed_df = pd.DataFrame(daily_parsedTweets)
    
    # Export daily_parsed_df as CSV for the date's tweets
    daily_parsed_df.to_csv(f"{file_path}.csv", index=False)
    
    # convert raw tweets for day JSON responses array into .json file
    with open(f"{file_path}_raw.json", "w") as raw_tweets:
        json.dump(daily_rawTweets, raw_tweets)
    
    # Print message for how many tweets returned per date
    print(f"{len(daily_parsedTweets)} tweets fetched for Day {date + 1}: 2022{from_date}\n")
    
    from_date += 1
    to_date += 1
    
    # Time sleep for 60 seconds
    print("Day " + str(date + 1) + " Sleep Start Time : %s" % time.ctime())
    time.sleep(60)
    print("Day " + str(date + 1) + " Sleep End Time : %s" % time.ctime() + "\n")
    

# convert big data raw tweets JSON responses array for all tweets into .json file
with open("../res/big_data_tweets_raw.json", "w") as raw_tweets:
    json.dump(rawTweets, raw_tweets)
    # Expected large file size. Will be stored in s3 bucket.
    
    
# Read big data parsed tweets into pandas dataframe
tweet_df = pd.DataFrame(parsedTweets)
# Out:
# Fetching Day 1 Tweets Start Time : Fri Nov 18 14:41:55 2022
# Fetching Tweets for Day 1 ...
#
# Fetched and Parsed All Tweets for Day 1.
# Fetching and Parsing Day 1 Tweets End Time : Fri Nov 18 14:42:12 2022
#
# 7582 tweets fetched for Day 1: 20221103
#
# Day 1 Sleep Start Time : Fri Nov 18 14:42:13 2022
# Day 1 Sleep End Time : Fri Nov 18 14:43:13 2022
#
# Fetching Day 2 Tweets Start Time : Fri Nov 18 14:43:13 2022
# Fetching Tweets for Day 2 ...
#
# Fetched and Parsed All Tweets for Day 2.
# Fetching and Parsing Day 2 Tweets End Time : Fri Nov 18 14:43:25 2022
#
# 6984 tweets fetched for Day 2: 20221104
#
# Day 2 Sleep Start Time : Fri Nov 18 14:43:26 2022
# Day 2 Sleep End Time : Fri Nov 18 14:44:26 2022
#
# Fetching Day 3 Tweets Start Time : Fri Nov 18 14:44:26 2022
# Fetching Tweets for Day 3 ...
#
# Fetched and Parsed All Tweets for Day 3.
# Fetching and Parsing Day 3 Tweets End Time : Fri Nov 18 14:44:38 2022
#
# 5763 tweets fetched for Day 3: 20221105
#
# Day 3 Sleep Start Time : Fri Nov 18 14:44:38 2022
# Day 3 Sleep End Time : Fri Nov 18 14:45:38 2022
#
# Fetching Day 4 Tweets Start Time : Fri Nov 18 14:45:38 2022
# Fetching Tweets for Day 4 ...
#
# Fetched and Parsed All Tweets for Day 4.
# Fetching and Parsing Day 4 Tweets End Time : Fri Nov 18 14:45:50 2022
#
# 5329 tweets fetched for Day 4: 20221106
#
# Day 4 Sleep Start Time : Fri Nov 18 14:45:51 2022
# Day 4 Sleep End Time : Fri Nov 18 14:46:51 2022
#
# Fetching Day 5 Tweets Start Time : Fri Nov 18 14:46:51 2022
# Fetching Tweets for Day 5 ...
#
# Fetched and Parsed All Tweets for Day 5.
# Fetching and Parsing Day 5 Tweets End Time : Fri Nov 18 14:47:03 2022
#
# 6578 tweets fetched for Day 5: 20221107
#
# Day 5 Sleep Start Time : Fri Nov 18 14:47:04 2022
# Day 5 Sleep End Time : Fri Nov 18 14:48:04 2022
#
# Fetching Day 6 Tweets Start Time : Fri Nov 18 14:48:04 2022
# Fetching Tweets for Day 6 ...
#
# Fetched and Parsed All Tweets for Day 6.
# Fetching and Parsing Day 6 Tweets End Time : Fri Nov 18 14:48:20 2022
#
# 7632 tweets fetched for Day 6: 20221108
#
# Day 6 Sleep Start Time : Fri Nov 18 14:48:21 2022
# Day 6 Sleep End Time : Fri Nov 18 14:49:21 2022
#
# Fetching Day 7 Tweets Start Time : Fri Nov 18 14:49:21 2022
# Fetching Tweets for Day 7 ...
#
# Fetched and Parsed All Tweets for Day 7.
# Fetching and Parsing Day 7 Tweets End Time : Fri Nov 18 14:49:39 2022
#
# 9774 tweets fetched for Day 7: 20221109
#
# Day 7 Sleep Start Time : Fri Nov 18 14:49:40 2022
# Day 7 Sleep End Time : Fri Nov 18 14:50:40 2022
#
# Fetching Day 8 Tweets Start Time : Fri Nov 18 14:50:40 2022
# Fetching Tweets for Day 8 ...
#
# Fetched and Parsed All Tweets for Day 8.
# Fetching and Parsing Day 8 Tweets End Time : Fri Nov 18 14:50:55 2022
#
# 8329 tweets fetched for Day 8: 20221110
#
# Day 8 Sleep Start Time : Fri Nov 18 14:50:56 2022
# Day 8 Sleep End Time : Fri Nov 18 14:51:56 2022
#
# Fetching Day 9 Tweets Start Time : Fri Nov 18 14:51:56 2022
# Fetching Tweets for Day 9 ...
#
# Fetched and Parsed All Tweets for Day 9.
# Fetching and Parsing Day 9 Tweets End Time : Fri Nov 18 14:52:06 2022
#
# 5076 tweets fetched for Day 9: 20221111
#
# Day 9 Sleep Start Time : Fri Nov 18 14:52:07 2022
# Day 9 Sleep End Time : Fri Nov 18 14:53:07 2022
#
# Fetching Day 10 Tweets Start Time : Fri Nov 18 14:53:07 2022
# Fetching Tweets for Day 10 ...
#
# Fetched and Parsed All Tweets for Day 10.
# Fetching and Parsing Day 10 Tweets End Time : Fri Nov 18 14:53:15 2022
#
# 4492 tweets fetched for Day 10: 20221112
#
# Day 10 Sleep Start Time : Fri Nov 18 14:53:15 2022
# Day 10 Sleep End Time : Fri Nov 18 14:54:15 2022
#
# Fetching Day 11 Tweets Start Time : Fri Nov 18 14:54:15 2022
# Fetching Tweets for Day 11 ...
#
# Fetched and Parsed All Tweets for Day 11.
# Fetching and Parsing Day 11 Tweets End Time : Fri Nov 18 14:54:24 2022
#
# 5453 tweets fetched for Day 11: 20221113
#
# Day 11 Sleep Start Time : Fri Nov 18 14:54:25 2022
# Day 11 Sleep End Time : Fri Nov 18 14:55:25 2022

# %%
# Check tweets dataframe data types and missing values for each column
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72992 entries, 0 to 72991
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tweet_id           72992 non-null  object
#  1   date               72992 non-null  object
#  2   full_text          72992 non-null  object
#  3   tweet_type         72992 non-null  object
#  4   hashtags           10613 non-null  object
#  5   mentions           55129 non-null  object
#  6   user_id            72992 non-null  object
#  7   user_location      72794 non-null  object
#  8   geo                29 non-null     object
#  9   lat_coordinates    29 non-null     float64
#  10  lng_coordinates    29 non-null     float64
#  11  place_type         1973 non-null   object
#  12  place_name         1973 non-null   object
#  13  place_full_name    1973 non-null   object
#  14  country_code       1973 non-null   object
#  15  country            1973 non-null   object
#  16  prof_country       72392 non-null  object
#  17  prof_country_code  72392 non-null  object
#  18  prof_locality      39299 non-null  object
#  19  prof_region        63007 non-null  object
#  20  prof_sub_region    37776 non-null  object
#  21  prof_full_name     72392 non-null  object
#  22  prof_coord_lat     72392 non-null  float64
#  23  prof_coord_lng     72392 non-null  float64
#  24  reply_count        72992 non-null  int64
#  25  quote_count        72992 non-null  int64
#  26  likes_count        72992 non-null  int64
#  27  retweet_counts     72992 non-null  int64
#  28  hyperlink          72992 non-null  object
# dtypes: float64(4), int64(4), object(21)
# memory usage: 16.1+ MB

# %%
# drop 'geo', 'lat_coordinates', and 'lng_coordinates' columns for insufficient data
tweet_df.drop(['geo', 'lat_coordinates', 'lng_coordinates'], axis=1, inplace=True)
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72992 entries, 0 to 72991
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tweet_id           72992 non-null  object
#  1   date               72992 non-null  object
#  2   full_text          72992 non-null  object
#  3   tweet_type         72992 non-null  object
#  4   hashtags           10613 non-null  object
#  5   mentions           55129 non-null  object
#  6   user_id            72992 non-null  object
#  7   user_location      72794 non-null  object
#  8   place_type         1973 non-null   object
#  9   place_name         1973 non-null   object
#  10  place_full_name    1973 non-null   object
#  11  country_code       1973 non-null   object
#  12  country            1973 non-null   object
#  13  prof_country       72392 non-null  object
#  14  prof_country_code  72392 non-null  object
#  15  prof_locality      39299 non-null  object
#  16  prof_region        63007 non-null  object
#  17  prof_sub_region    37776 non-null  object
#  18  prof_full_name     72392 non-null  object
#  19  prof_coord_lat     72392 non-null  float64
#  20  prof_coord_lng     72392 non-null  float64
#  21  reply_count        72992 non-null  int64
#  22  quote_count        72992 non-null  int64
#  23  likes_count        72992 non-null  int64
#  24  retweet_counts     72992 non-null  int64
#  25  hyperlink          72992 non-null  object
# dtypes: float64(2), int64(4), object(20)
# memory usage: 14.5+ MB

# %%
# Check top 10 rows of tweets dataframe
tweet_df.head(10)
# Out:
#               tweet_id                            date  \
# 0  1588320083335467009  Thu Nov 03 23:59:52 +0000 2022
# 1  1588320019259469824  Thu Nov 03 23:59:36 +0000 2022
# 2  1588320006840160256  Thu Nov 03 23:59:33 +0000 2022
# 3  1588319891446272001  Thu Nov 03 23:59:06 +0000 2022
# 4  1588319866385477632  Thu Nov 03 23:59:00 +0000 2022
# 5  1588319827651104769  Thu Nov 03 23:58:51 +0000 2022
# 6  1588319810181529602  Thu Nov 03 23:58:46 +0000 2022
# 7  1588319807375433728  Thu Nov 03 23:58:46 +0000 2022
# 8  1588319706343124992  Thu Nov 03 23:58:22 +0000 2022
# 9  1588319697808019456  Thu Nov 03 23:58:20 +0000 2022
#
#                                            full_text      tweet_type hashtags  \
# 0  @UnnecRoughness A is Levis. \nB is KJ Jefferso...     Reply Tweet     None
# 1  Republican candidate's kids are almost KILLED ...  Original Tweet     None
# 2  @Jupiter62214807 @cjstheman_611 @BMC_MacDaddy ...     Reply Tweet     None
# 3  @davidhogg111 It’s 2022, get new talking point...     Reply Tweet     None
# 4  Watch: Gunman opens fire on Imran Khan https:/...  Original Tweet     None
# 5  @Stormof69 @VoteYesOn114 I’m always amused tha...     Reply Tweet     None
# 6  @ColinCowherd @DrHoodieMaddog What about kids ...     Reply Tweet     None
# 7  @Unnoble_Savage @brianleeellis @michaeljknowle...     Reply Tweet     None
# 8  @RobSchneider Let’s keep the 2nd Amendment and...     Reply Tweet     None
# 9  @davidhogg111 How many times a year are guns u...     Reply Tweet     None
#
#                                             mentions              user_id  \
# 0                                  [@UnnecRoughness]            531999121
# 1                                               None  1586027897579802624
# 2  [@Jupiter62214807, @cjstheman_611, @BMC_MacDad...   783106891274596352
# 3                                    [@davidhogg111]  1511111650199412739
# 4                                               None            287297482
# 5                        [@Stormof69, @VoteYesOn114]            412772316
# 6                   [@ColinCowherd, @DrHoodieMaddog]            147647057
# 7  [@Unnoble_Savage, @brianleeellis, @michaeljkno...  1040679839747825664
# 8                                    [@RobSchneider]  1586158533149499392
# 9                                    [@davidhogg111]  1527469162838253568
#
#     user_location place_type place_name  ...    prof_region   prof_sub_region  \
# 0   Arkansas, USA       None       None  ...       Arkansas              None
# 1   United States       None       None  ...           None              None
# 2   Virginia, USA       None       None  ...  West Virginia              None
# 3              MI       None       None  ...       Michigan              None
# 4            USA        None       None  ...           None              None
# 5  Manchester, CT       None       None  ...    Connecticut   Hartford County
# 6    Brooklyn, NY       None       None  ...       New York      Kings County
# 7     Willits, CA       None       None  ...     California  Mendocino County
# 8    Monterey, CA       None       None  ...     California   Monterey County
# 9             USA       None       None  ...           None              None
#
#                            prof_full_name prof_coord_lat prof_coord_lng  \
# 0                 Arkansas, United States      -92.50044       34.75037
# 1                           United States      -98.50000       39.76000
# 2            West Virginia, United States      -80.50009       38.50038
# 3                 Michigan, United States      -85.50033       44.25029
# 4                           United States      -98.50000       39.76000
# 5  Manchester, Connecticut, United States      -72.52148       41.77593
# 6       Brooklyn, New York, United States      -73.94958       40.65010
# 7      Willits, California, United States     -123.35557       39.40961
# 8     Monterey, California, United States     -121.89468       36.60024
# 9                           United States      -98.50000       39.76000
#
#   reply_count quote_count likes_count retweet_counts  \
# 0           0           0           6              0
# 1           0           0           0              0
# 2           0           0           1              0
# 3           0           0           8              0
# 4           0           0           0              0
# 5           0           0           4              0
# 6           0           0           0              0
# 7           0           0           0              0
# 8           0           0           0              0
# 9           0           0           0              0
#
#                                            hyperlink
# 0  https://twitter.com/twitter/status/15883200833...
# 1  https://twitter.com/twitter/status/15883200192...
# 2  https://twitter.com/twitter/status/15883200068...
# 3  https://twitter.com/twitter/status/15883198914...
# 4  https://twitter.com/twitter/status/15883198663...
# 5  https://twitter.com/twitter/status/15883198276...
# 6  https://twitter.com/twitter/status/15883198101...
# 7  https://twitter.com/twitter/status/15883198073...
# 8  https://twitter.com/twitter/status/15883197063...
# 9  https://twitter.com/twitter/status/15883196978...
#
# [10 rows x 26 columns]

# %%
# Confirm results for user.location and profile geo data parsing
tweet_df.loc[:, ['user_location', 'prof_country', 'prof_country_code', 'prof_locality', 'prof_region', 'prof_sub_region', 'prof_full_name']].head(10)
# Out:
#     user_location   prof_country prof_country_code prof_locality  \
# 0   Arkansas, USA  United States                US          None
# 1   United States  United States                US          None
# 2   Virginia, USA  United States                US          None
# 3              MI  United States                US          None
# 4            USA   United States                US          None
# 5  Manchester, CT  United States                US    Manchester
# 6    Brooklyn, NY  United States                US      Brooklyn
# 7     Willits, CA  United States                US       Willits
# 8    Monterey, CA  United States                US      Monterey
# 9             USA  United States                US          None
#
#      prof_region   prof_sub_region                          prof_full_name
# 0       Arkansas              None                 Arkansas, United States
# 1           None              None                           United States
# 2  West Virginia              None            West Virginia, United States
# 3       Michigan              None                 Michigan, United States
# 4           None              None                           United States
# 5    Connecticut   Hartford County  Manchester, Connecticut, United States
# 6       New York      Kings County       Brooklyn, New York, United States
# 7     California  Mendocino County      Willits, California, United States
# 8     California   Monterey County     Monterey, California, United States
# 9           None              None                           United States

# %%
# Check top 30 counties value counts
tweet_df['prof_sub_region'].value_counts()[0:30]
# Out:
# Los Angeles County      1774
# Cook County             1534
# Harris County           1100
# Orange County           1040
# Dallas County           1032
# Multnomah County         911
# Philadelphia County      866
# Travis County            866
# King County              818
# Fulton County            734
# Suffolk County           594
# Maricopa County          579
# Tarrant County           563
# Bexar County             535
# Clark County             491
# San Diego County         450
# Kings County             426
# Jackson County           426
# Miami-Dade County        425
# Marion County            418
# Palm Beach County        364
# Allegheny County         354
# Montgomery County        345
# Denver County            330
# San Francisco County     327
# Jefferson County         326
# Franklin County          321
# Oklahoma County          311
# City of Saint Louis      299
# Hillsborough County      295
# Name: prof_sub_region, dtype: int64

# %%
# Check top 30 cities values counts
tweet_df['prof_locality'].value_counts()[0:30]
# Out:
# Chicago              1405
# Los Angeles          1281
# Houston              1020
# Dallas                949
# Portland              936
# New York City         935
# Philadelphia          866
# Austin                855
# Atlanta               694
# Seattle               642
# Washington, D. C.     585
# Florida               583
# Boston                528
# San Antonio           525
# Fort Worth            474
# Brooklyn              417
# Phoenix               377
# Las Vegas             367
# San Diego             353
# Miami                 343
# Denver                331
# San Francisco         327
# Kansas City           325
# Pittsburgh            321
# St. Louis             299
# Oklahoma City         298
# Indianapolis          276
# Tampa                 253
# Charlotte             242
# Columbus              242
# Name: prof_locality, dtype: int64

# %%
# Check distribution of tweet types
tweet_df['tweet_type'].value_counts()
# Out:
# Reply Tweet       52264
# Original Tweet    20720
# Quote Tweet           8
# Name: tweet_type, dtype: int64

# %%
# Remove Quote Tweet tweet types
tweet_df = tweet_df[tweet_df['tweet_type'] != "Quote Tweet"]

# %%
# Confirm removing Quote Tweets
tweet_df['tweet_type'].value_counts()
# Out:
# Reply Tweet       52264
# Original Tweet    20720
# Name: tweet_type, dtype: int64

# %%
# Check for unique values and respective counts in 'country_code' column
tweet_df['prof_country_code'].value_counts()
# Out:
# US    72331
# GH       18
# GB        6
# ES        4
# ZA        4
# CD        2
# VC        2
# PH        2
# TH        2
# CN        2
# KM        2
# FR        1
# BA        1
# CF        1
# AR        1
# TN        1
# GE        1
# UY        1
# MA        1
# PG        1
# Name: prof_country_code, dtype: int64

# %%
# Check for unique values and respective counts in 'prof_country' column
tweet_df['prof_country'].value_counts()
# Out:
# United States                             72331
# Ghana                                        18
# United Kingdom                                6
# Spain                                         4
# South Africa                                  4
# Congo (The Democratic Republic of the)        2
# Saint Vincent and the Grenadines              2
# Philippines                                   2
# Thailand                                      2
# China                                         2
# Comoros                                       2
# France                                        1
# Bosnia and Herzegovina                        1
# Central African Republic                      1
# Argentina                                     1
# Tunisia                                       1
# Georgia                                       1
# Uruguay                                       1
# Morocco                                       1
# Papua New Guinea                              1
# Name: prof_country, dtype: int64

# %%
# Check rows with non-null values in 'country_code' that are not 'US' for conflicts with profile geo data
tweet_df.loc[lambda df: (df['prof_country_code'] == 'GH') | (df['prof_country_code'] == 'GB') | (df['prof_country_code'] == 'ES')].T
# Out:
#                                                                1295   \
# tweet_id                                         1588274567612694538
# date                                  Thu Nov 03 20:59:00 +0000 2022
# full_text          'My teacher is dead': Girl, 10, trapped in sch...
# tweet_type                                            Original Tweet
# hashtags                   [#Uvalde, #UvaldeMassacre, #uvaldestrong]
# mentions                                                        None
# user_id                                                     17895820
# user_location                                                 London
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                          United Kingdom
# prof_country_code                                                 GB
# prof_locality                                                 London
# prof_region                                                  England
# prof_sub_region                                       Greater London
# prof_full_name                       London, England, United Kingdom
# prof_coord_lat                                              -0.12574
# prof_coord_lng                                              51.50853
# reply_count                                                        0
# quote_count                                                        0
# likes_count                                                        2
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15882745676...
#
#                                                                14687  \
# tweet_id                                         1589038041108451329
# date                                  Sat Nov 05 23:32:46 +0000 2022
# full_text          @flashwizardjr @JoeBiden You do know our count...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions                                 [@flashwizardjr, @JoeBiden]
# user_id                                          1555116935381237762
# user_location                                   Minas Tirith, Gondor
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                                   Spain
# prof_country_code                                                 ES
# prof_locality                             Villanueva del Río y Minas
# prof_region                                                Andalusia
# prof_sub_region                                 Provincia de Sevilla
# prof_full_name          Villanueva del Río y Minas, Andalusia, Spain
# prof_coord_lat                                              -5.71369
# prof_coord_lng                                              37.65502
# reply_count                                                        0
# quote_count                                                        0
# likes_count                                                        6
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15890380411...
#
#                                                                21775  \
# tweet_id                                         1589333929034940418
# date                                  Sun Nov 06 19:08:31 +0000 2022
# full_text          @DeltaLowda @FordFischer @IamHawkNewsome @FBI ...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions           [@DeltaLowda, @FordFischer, @IamHawkNewsome, @...
# user_id                                                     22033036
# user_location                                         United Kingdom
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                          United Kingdom
# prof_country_code                                                 GB
# prof_locality                                                   None
# prof_region                                                     None
# prof_sub_region                                                 None
# prof_full_name                                        United Kingdom
# prof_coord_lat                                              -2.69531
# prof_coord_lng                                              54.75844
# reply_count                                                        0
# quote_count                                                        0
# likes_count                                                        3
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15893339290...
#
#                                                                42218  \
# tweet_id                                         1590424008176340992
# date                                  Wed Nov 09 19:20:06 +0000 2022
# full_text          @captain_kityy @rayeahri @superwong18 @beatbya...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions           [@captain_kityy, @rayeahri, @superwong18, @bea...
# user_id                                          1555116935381237762
# user_location                                   Minas Tirith, Gondor
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                                   Spain
# prof_country_code                                                 ES
# prof_locality                             Villanueva del Río y Minas
# prof_region                                                Andalusia
# prof_sub_region                                 Provincia de Sevilla
# prof_full_name          Villanueva del Río y Minas, Andalusia, Spain
# prof_coord_lat                                              -5.71369
# prof_coord_lng                                              37.65502
# reply_count                                                        1
# quote_count                                                        0
# likes_count                                                        0
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15904240081...
#
#                                                                43442  \
# tweet_id                                         1590389813248921600
# date                                  Wed Nov 09 17:04:14 +0000 2022
# full_text          @MiKeysundrthmat @munchindaglizzy @Jellyjon_91...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions           [@MiKeysundrthmat, @munchindaglizzy, @Jellyjon...
# user_id                                          1555116935381237762
# user_location                                   Minas Tirith, Gondor
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                                   Spain
# prof_country_code                                                 ES
# prof_locality                             Villanueva del Río y Minas
# prof_region                                                Andalusia
# prof_sub_region                                 Provincia de Sevilla
# prof_full_name          Villanueva del Río y Minas, Andalusia, Spain
# prof_coord_lat                                              -5.71369
# prof_coord_lng                                              37.65502
# reply_count                                                        0
# quote_count                                                        0
# likes_count                                                        2
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15903898132...
#
#                                                                47787  \
# tweet_id                                         1590193957543505921
# date                                  Wed Nov 09 04:05:58 +0000 2022
# full_text          @1andonlybrittne I think with the demographics...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions                                          [@1andonlybrittne]
# user_id                                          1519163177711321088
# user_location                                           Vatican City
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                          United Kingdom
# prof_country_code                                                 GB
# prof_locality                                         City of London
# prof_region                                                  England
# prof_sub_region                                       Greater London
# prof_full_name               City of London, England, United Kingdom
# prof_coord_lat                                              -0.09184
# prof_coord_lng                                              51.51279
# reply_count                                                        0
# quote_count                                                        0
# likes_count                                                        1
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15901939575...
#
#                                                                47940  \
# tweet_id                                         1590190511163592704
# date                                  Wed Nov 09 03:52:16 +0000 2022
# full_text          @1andonlybrittne Running Beto for a third time...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions                                          [@1andonlybrittne]
# user_id                                          1519163177711321088
# user_location                                           Vatican City
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                          United Kingdom
# prof_country_code                                                 GB
# prof_locality                                         City of London
# prof_region                                                  England
# prof_sub_region                                       Greater London
# prof_full_name               City of London, England, United Kingdom
# prof_coord_lat                                              -0.09184
# prof_coord_lng                                              51.51279
# reply_count                                                        1
# quote_count                                                        0
# likes_count                                                        1
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15901905111...
#
#                                                                57427  \
# tweet_id                                         1590514576894099456
# date                                  Thu Nov 10 01:20:00 +0000 2022
# full_text          @ElieNYC @davidhogg111 Funny how you care abou...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions                                   [@ElieNYC, @davidhogg111]
# user_id                                          1555116935381237762
# user_location                                   Minas Tirith, Gondor
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                                   Spain
# prof_country_code                                                 ES
# prof_locality                             Villanueva del Río y Minas
# prof_region                                                Andalusia
# prof_sub_region                                 Provincia de Sevilla
# prof_full_name          Villanueva del Río y Minas, Andalusia, Spain
# prof_coord_lat                                              -5.71369
# prof_coord_lng                                              37.65502
# reply_count                                                        0
# quote_count                                                        0
# likes_count                                                        0
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15905145768...
#
#                                                                62924  \
# tweet_id                                         1590861393406078976
# date                                  Fri Nov 11 00:18:07 +0000 2022
# full_text          @davidhogg111 STOP #GunControl BS https://t.co...
# tweet_type                                               Reply Tweet
# hashtags                                               [#GunControl]
# mentions                                             [@davidhogg111]
# user_id                                                     26282272
# user_location                                                Saturn
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                          United Kingdom
# prof_country_code                                                 GB
# prof_locality                                                   None
# prof_region                                                     None
# prof_sub_region                                                 None
# prof_full_name                                        United Kingdom
# prof_coord_lat                                              -2.69531
# prof_coord_lng                                              54.75844
# reply_count                                                        0
# quote_count                                                        0
# likes_count                                                        0
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15908613934...
#
#                                                                68963  ...  \
# tweet_id                                         1591867895440887809  ...
# date                                  Sun Nov 13 18:57:36 +0000 2022  ...
# full_text          @The1Hauntings @JimboUSA1776 @KeelKeel13 @Laca...  ...
# tweet_type                                               Reply Tweet  ...
# hashtags                                                        None  ...
# mentions           [@The1Hauntings, @JimboUSA1776, @KeelKeel13, @...  ...
# user_id                                                    105926399  ...
# user_location                                           Accra, Ghana  ...
# place_type                                                      None  ...
# place_name                                                      None  ...
# place_full_name                                                 None  ...
# country_code                                                    None  ...
# country                                                         None  ...
# prof_country                                                   Ghana  ...
# prof_country_code                                                 GH  ...
# prof_locality                                                   None  ...
# prof_region                                            Greater Accra  ...
# prof_sub_region                                                 None  ...
# prof_full_name                                  Greater Accra, Ghana  ...
# prof_coord_lat                                                   0.0  ...
# prof_coord_lng                                                  5.75  ...
# reply_count                                                        0  ...
# quote_count                                                        0  ...
# likes_count                                                        0  ...
# retweet_counts                                                     0  ...
# hyperlink          https://twitter.com/twitter/status/15918678954...  ...
#
#                                                                70222  \
# tweet_id                                         1591818222789353474
# date                                  Sun Nov 13 15:40:13 +0000 2022
# full_text          @Derrick47886845 @DianaHe50951535 @kali8989 @r...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions           [@Derrick47886845, @DianaHe50951535, @kali8989...
# user_id                                                    105926399
# user_location                                           Accra, Ghana
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                                   Ghana
# prof_country_code                                                 GH
# prof_locality                                                   None
# prof_region                                            Greater Accra
# prof_sub_region                                                 None
# prof_full_name                                  Greater Accra, Ghana
# prof_coord_lat                                                   0.0
# prof_coord_lng                                                  5.75
# reply_count                                                        0
# quote_count                                                        0
# likes_count                                                        1
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15918182227...
#
#                                                                70227  \
# tweet_id                                         1591818104639733762
# date                                  Sun Nov 13 15:39:45 +0000 2022
# full_text          @Derrick47886845 @DianaHe50951535 @kali8989 @r...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions           [@Derrick47886845, @DianaHe50951535, @kali8989...
# user_id                                                    105926399
# user_location                                           Accra, Ghana
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                                   Ghana
# prof_country_code                                                 GH
# prof_locality                                                   None
# prof_region                                            Greater Accra
# prof_sub_region                                                 None
# prof_full_name                                  Greater Accra, Ghana
# prof_coord_lat                                                   0.0
# prof_coord_lng                                                  5.75
# reply_count                                                        0
# quote_count                                                        0
# likes_count                                                        0
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15918181046...
#
#                                                                70238  \
# tweet_id                                         1591817689294835712
# date                                  Sun Nov 13 15:38:06 +0000 2022
# full_text          @Derrick47886845 @DianaHe50951535 @kali8989 @r...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions           [@Derrick47886845, @DianaHe50951535, @kali8989...
# user_id                                                    105926399
# user_location                                           Accra, Ghana
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                                   Ghana
# prof_country_code                                                 GH
# prof_locality                                                   None
# prof_region                                            Greater Accra
# prof_sub_region                                                 None
# prof_full_name                                  Greater Accra, Ghana
# prof_coord_lat                                                   0.0
# prof_coord_lng                                                  5.75
# reply_count                                                        0
# quote_count                                                        0
# likes_count                                                        0
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15918176892...
#
#                                                                70241  \
# tweet_id                                         1591817591500464129
# date                                  Sun Nov 13 15:37:43 +0000 2022
# full_text          @Derrick47886845 @DianaHe50951535 @kali8989 @r...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions           [@Derrick47886845, @DianaHe50951535, @kali8989...
# user_id                                                    105926399
# user_location                                           Accra, Ghana
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                                   Ghana
# prof_country_code                                                 GH
# prof_locality                                                   None
# prof_region                                            Greater Accra
# prof_sub_region                                                 None
# prof_full_name                                  Greater Accra, Ghana
# prof_coord_lat                                                   0.0
# prof_coord_lng                                                  5.75
# reply_count                                                        1
# quote_count                                                        0
# likes_count                                                        0
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15918175915...
#
#                                                                70264  \
# tweet_id                                         1591816591997820928
# date                                  Sun Nov 13 15:33:44 +0000 2022
# full_text          @Derrick47886845 @DianaHe50951535 @kali8989 @r...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions           [@Derrick47886845, @DianaHe50951535, @kali8989...
# user_id                                                    105926399
# user_location                                           Accra, Ghana
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                                   Ghana
# prof_country_code                                                 GH
# prof_locality                                                   None
# prof_region                                            Greater Accra
# prof_sub_region                                                 None
# prof_full_name                                  Greater Accra, Ghana
# prof_coord_lat                                                   0.0
# prof_coord_lng                                                  5.75
# reply_count                                                        2
# quote_count                                                        0
# likes_count                                                        1
# retweet_counts                                                     1
# hyperlink          https://twitter.com/twitter/status/15918165919...
#
#                                                                70297  \
# tweet_id                                         1591815094484480000
# date                                  Sun Nov 13 15:27:47 +0000 2022
# full_text          @Derrick47886845 @DianaHe50951535 @kali8989 @r...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions           [@Derrick47886845, @DianaHe50951535, @kali8989...
# user_id                                                    105926399
# user_location                                           Accra, Ghana
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                                   Ghana
# prof_country_code                                                 GH
# prof_locality                                                   None
# prof_region                                            Greater Accra
# prof_sub_region                                                 None
# prof_full_name                                  Greater Accra, Ghana
# prof_coord_lat                                                   0.0
# prof_coord_lng                                                  5.75
# reply_count                                                        2
# quote_count                                                        0
# likes_count                                                        2
# retweet_counts                                                     1
# hyperlink          https://twitter.com/twitter/status/15918150944...
#
#                                                                70307  \
# tweet_id                                         1591814735137280000
# date                                  Sun Nov 13 15:26:22 +0000 2022
# full_text          @Derrick47886845 @DianaHe50951535 @kali8989 @r...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions           [@Derrick47886845, @DianaHe50951535, @kali8989...
# user_id                                                    105926399
# user_location                                           Accra, Ghana
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                                   Ghana
# prof_country_code                                                 GH
# prof_locality                                                   None
# prof_region                                            Greater Accra
# prof_sub_region                                                 None
# prof_full_name                                  Greater Accra, Ghana
# prof_coord_lat                                                   0.0
# prof_coord_lng                                                  5.75
# reply_count                                                        1
# quote_count                                                        0
# likes_count                                                        0
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15918147351...
#
#                                                                70317  \
# tweet_id                                         1591814456040099841
# date                                  Sun Nov 13 15:25:15 +0000 2022
# full_text          @Derrick47886845 @DianaHe50951535 @kali8989 @r...
# tweet_type                                               Reply Tweet
# hashtags                                   [#BackTheBlue, #BlueLine]
# mentions           [@Derrick47886845, @DianaHe50951535, @kali8989...
# user_id                                                    105926399
# user_location                                           Accra, Ghana
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                                   Ghana
# prof_country_code                                                 GH
# prof_locality                                                   None
# prof_region                                            Greater Accra
# prof_sub_region                                                 None
# prof_full_name                                  Greater Accra, Ghana
# prof_coord_lat                                                   0.0
# prof_coord_lng                                                  5.75
# reply_count                                                        2
# quote_count                                                        0
# likes_count                                                        1
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15918144560...
#
#                                                                70354  \
# tweet_id                                         1591812529600315392
# date                                  Sun Nov 13 15:17:36 +0000 2022
# full_text          @Derrick47886845 @DianaHe50951535 @kali8989 @r...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions           [@Derrick47886845, @DianaHe50951535, @kali8989...
# user_id                                                    105926399
# user_location                                           Accra, Ghana
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                                   Ghana
# prof_country_code                                                 GH
# prof_locality                                                   None
# prof_region                                            Greater Accra
# prof_sub_region                                                 None
# prof_full_name                                  Greater Accra, Ghana
# prof_coord_lat                                                   0.0
# prof_coord_lng                                                  5.75
# reply_count                                                        1
# quote_count                                                        0
# likes_count                                                        3
# retweet_counts                                                     1
# hyperlink          https://twitter.com/twitter/status/15918125296...
#
#                                                                71082
# tweet_id                                         1591770598711099392
# date                                  Sun Nov 13 12:30:59 +0000 2022
# full_text          @christycarruth @GavinClimie Gun ownership is ...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions                             [@christycarruth, @GavinClimie]
# user_id                                          1545103667124224001
# user_location                                        London, England
# place_type                                                      None
# place_name                                                      None
# place_full_name                                                 None
# country_code                                                    None
# country                                                         None
# prof_country                                          United Kingdom
# prof_country_code                                                 GB
# prof_locality                                                 London
# prof_region                                                  England
# prof_sub_region                                       Greater London
# prof_full_name                       London, England, United Kingdom
# prof_coord_lat                                              -0.12574
# prof_coord_lng                                              51.50853
# reply_count                                                        0
# quote_count                                                        0
# likes_count                                                        3
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15917705987...
#
# [26 rows x 28 columns]

# %%
# Filter for only rows where prof_country_code is 'US'
tweet_df = tweet_df[tweet_df['prof_country_code'] == 'US']
# return value counts of 'prof_country_code' and 'prof_country' to confirm only tweets from US profiles exist in data
print(f"Country Code Counts:\n {tweet_df['prof_country_code'].value_counts()}\n\nCountry Name Counts:\n {tweet_df['prof_country'].value_counts()}")
# Out:
# Country Code Counts:
#  US    72331
# Name: prof_country_code, dtype: int64
#
# Country Name Counts:
#  United States    72331
# Name: prof_country, dtype: int64

# %%
# Drop 'prof_country_code'
tweet_df.drop(['prof_country_code'], axis=1, inplace=True)

# %%
# Check top 30 user locations value counts
tweet_df['user_location'].value_counts()[0:30]
# Out:
# United States        4764
# USA                  2581
# Texas, USA           1605
# Florida, USA         1205
# California, USA      1097
# Washington, DC       1097
# Texas                1010
# Chicago, IL           976
# Los Angeles, CA       763
# Houston, TX           735
# New York, NY          699
# New York, USA         693
# Dallas, TX            655
# Portland, OR          611
# Pennsylvania, USA     590
# Philadelphia, PA      588
# Austin, TX            557
# New Jersey, USA       504
# Washington, USA       473
# Atlanta, GA           472
# New York City         462
# Fort Worth, TX        426
# New York              424
# Seattle, WA           420
# Michigan, USA         405
# Ohio, USA             395
# San Antonio, TX       384
# California            355
# Arizona, USA          352
# Colorado, USA         350
# Name: user_location, dtype: int64

# %%
# Check top 30 prof_full_name value counts
tweet_df['prof_full_name'].value_counts()[0:30]
# Out:
# United States                                         9365
# Texas, United States                                  3268
# New York, United States                               2955
# California, United States                             1732
# Washington, D.C., United States                       1563
# Chicago, Illinois, United States                      1405
# Los Angeles, California, United States                1280
# Florida, United States                                1231
# New Jersey, United States                             1030
# Houston, Texas, United States                         1018
# Dallas, Texas, United States                           947
# New York City, New York, United States                 935
# Pennsylvania, United States                            918
# Portland, Oregon, United States                        906
# Philadelphia, Pennsylvania, United States              866
# Austin, Texas, United States                           854
# Ohio, United States                                    742
# Michigan, United States                                723
# Atlanta, Georgia, United States                        694
# Oregon, United States                                  658
# West Virginia, United States                           652
# Seattle, Washington, United States                     642
# Washington, D. C., Washington, D.C., United States     585
# Florida, New York, United States                       582
# North Carolina, United States                          540
# Arizona, United States                                 538
# Colorado, United States                                535
# Boston, Massachusetts, United States                   527
# San Antonio, Texas, United States                      518
# Fort Worth, Texas, United States                       474
# Name: prof_full_name, dtype: int64

# %%
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72331 entries, 0 to 72991
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweet_id         72331 non-null  object
#  1   date             72331 non-null  object
#  2   full_text        72331 non-null  object
#  3   tweet_type       72331 non-null  object
#  4   hashtags         10552 non-null  object
#  5   mentions         54574 non-null  object
#  6   user_id          72331 non-null  object
#  7   user_location    72331 non-null  object
#  8   place_type       1964 non-null   object
#  9   place_name       1964 non-null   object
#  10  place_full_name  1964 non-null   object
#  11  country_code     1964 non-null   object
#  12  country          1964 non-null   object
#  13  prof_country     72331 non-null  object
#  14  prof_locality    39278 non-null  object
#  15  prof_region      62966 non-null  object
#  16  prof_sub_region  37758 non-null  object
#  17  prof_full_name   72331 non-null  object
#  18  prof_coord_lat   72331 non-null  float64
#  19  prof_coord_lng   72331 non-null  float64
#  20  reply_count      72331 non-null  int64
#  21  quote_count      72331 non-null  int64
#  22  likes_count      72331 non-null  int64
#  23  retweet_counts   72331 non-null  int64
#  24  hyperlink        72331 non-null  object
# dtypes: float64(2), int64(4), object(19)
# memory usage: 14.3+ MB

# %%
# drop all columns that are redundant and/ or contain more null values than other column carrying the same categorical information
tweet_df.drop(['user_location', 'place_type', 'place_name', 'place_full_name', 'country_code', 'country', 'prof_full_name'], axis=1, inplace=True)

# %%
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72331 entries, 0 to 72991
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweet_id         72331 non-null  object
#  1   date             72331 non-null  object
#  2   full_text        72331 non-null  object
#  3   tweet_type       72331 non-null  object
#  4   hashtags         10552 non-null  object
#  5   mentions         54574 non-null  object
#  6   user_id          72331 non-null  object
#  7   prof_country     72331 non-null  object
#  8   prof_locality    39278 non-null  object
#  9   prof_region      62966 non-null  object
#  10  prof_sub_region  37758 non-null  object
#  11  prof_coord_lat   72331 non-null  float64
#  12  prof_coord_lng   72331 non-null  float64
#  13  reply_count      72331 non-null  int64
#  14  quote_count      72331 non-null  int64
#  15  likes_count      72331 non-null  int64
#  16  retweet_counts   72331 non-null  int64
#  17  hyperlink        72331 non-null  object
# dtypes: float64(2), int64(4), object(12)
# memory usage: 10.5+ MB

# %%
# Rename columns for ease of interpretation
tweet_df.rename(columns={'prof_country': 'country', 'prof_locality': 'city', 'prof_region': 'state', 'prof_sub_region': 'county', 'prof_coord_lat': 'latitude', 'prof_coord_lng': 'longitude'}, inplace=True)

# %%
# Confirm column name changes
tweet_df.columns
# Out:
# Index(['tweet_id', 'date', 'full_text', 'tweet_type', 'hashtags', 'mentions',
#        'user_id', 'country', 'city', 'state', 'county', 'latitude',
#        'longitude', 'reply_count', 'quote_count', 'likes_count',
#        'retweet_counts', 'hyperlink'],
#       dtype='object')

# %%
# Change order of columns
tweet_df = tweet_df.loc[:,['tweet_id', 'date', 'full_text', 'tweet_type', 'hashtags', 'mentions',
                'user_id', 'city', 'county', 'state', 'country', 'latitude',
                'longitude', 'reply_count', 'quote_count', 'likes_count',
                'retweet_counts', 'hyperlink']]

# %%
# Confirm column changes with corrects row values
tweet_df.head(10)
# Out:
#               tweet_id                            date  \
# 0  1588320083335467009  Thu Nov 03 23:59:52 +0000 2022
# 1  1588320019259469824  Thu Nov 03 23:59:36 +0000 2022
# 2  1588320006840160256  Thu Nov 03 23:59:33 +0000 2022
# 3  1588319891446272001  Thu Nov 03 23:59:06 +0000 2022
# 4  1588319866385477632  Thu Nov 03 23:59:00 +0000 2022
# 5  1588319827651104769  Thu Nov 03 23:58:51 +0000 2022
# 6  1588319810181529602  Thu Nov 03 23:58:46 +0000 2022
# 7  1588319807375433728  Thu Nov 03 23:58:46 +0000 2022
# 8  1588319706343124992  Thu Nov 03 23:58:22 +0000 2022
# 9  1588319697808019456  Thu Nov 03 23:58:20 +0000 2022
#
#                                            full_text      tweet_type hashtags  \
# 0  @UnnecRoughness A is Levis. \nB is KJ Jefferso...     Reply Tweet     None
# 1  Republican candidate's kids are almost KILLED ...  Original Tweet     None
# 2  @Jupiter62214807 @cjstheman_611 @BMC_MacDaddy ...     Reply Tweet     None
# 3  @davidhogg111 It’s 2022, get new talking point...     Reply Tweet     None
# 4  Watch: Gunman opens fire on Imran Khan https:/...  Original Tweet     None
# 5  @Stormof69 @VoteYesOn114 I’m always amused tha...     Reply Tweet     None
# 6  @ColinCowherd @DrHoodieMaddog What about kids ...     Reply Tweet     None
# 7  @Unnoble_Savage @brianleeellis @michaeljknowle...     Reply Tweet     None
# 8  @RobSchneider Let’s keep the 2nd Amendment and...     Reply Tweet     None
# 9  @davidhogg111 How many times a year are guns u...     Reply Tweet     None
#
#                                             mentions              user_id  \
# 0                                  [@UnnecRoughness]            531999121
# 1                                               None  1586027897579802624
# 2  [@Jupiter62214807, @cjstheman_611, @BMC_MacDad...   783106891274596352
# 3                                    [@davidhogg111]  1511111650199412739
# 4                                               None            287297482
# 5                        [@Stormof69, @VoteYesOn114]            412772316
# 6                   [@ColinCowherd, @DrHoodieMaddog]            147647057
# 7  [@Unnoble_Savage, @brianleeellis, @michaeljkno...  1040679839747825664
# 8                                    [@RobSchneider]  1586158533149499392
# 9                                    [@davidhogg111]  1527469162838253568
#
#          city            county          state        country   latitude  \
# 0        None              None       Arkansas  United States  -92.50044
# 1        None              None           None  United States  -98.50000
# 2        None              None  West Virginia  United States  -80.50009
# 3        None              None       Michigan  United States  -85.50033
# 4        None              None           None  United States  -98.50000
# 5  Manchester   Hartford County    Connecticut  United States  -72.52148
# 6    Brooklyn      Kings County       New York  United States  -73.94958
# 7     Willits  Mendocino County     California  United States -123.35557
# 8    Monterey   Monterey County     California  United States -121.89468
# 9        None              None           None  United States  -98.50000
#
#    longitude  reply_count  quote_count  likes_count  retweet_counts  \
# 0   34.75037            0            0            6               0
# 1   39.76000            0            0            0               0
# 2   38.50038            0            0            1               0
# 3   44.25029            0            0            8               0
# 4   39.76000            0            0            0               0
# 5   41.77593            0            0            4               0
# 6   40.65010            0            0            0               0
# 7   39.40961            0            0            0               0
# 8   36.60024            0            0            0               0
# 9   39.76000            0            0            0               0
#
#                                            hyperlink
# 0  https://twitter.com/twitter/status/15883200833...
# 1  https://twitter.com/twitter/status/15883200192...
# 2  https://twitter.com/twitter/status/15883200068...
# 3  https://twitter.com/twitter/status/15883198914...
# 4  https://twitter.com/twitter/status/15883198663...
# 5  https://twitter.com/twitter/status/15883198276...
# 6  https://twitter.com/twitter/status/15883198101...
# 7  https://twitter.com/twitter/status/15883198073...
# 8  https://twitter.com/twitter/status/15883197063...
# 9  https://twitter.com/twitter/status/15883196978...

# %%
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72331 entries, 0 to 72991
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        72331 non-null  object
#  1   date            72331 non-null  object
#  2   full_text       72331 non-null  object
#  3   tweet_type      72331 non-null  object
#  4   hashtags        10552 non-null  object
#  5   mentions        54574 non-null  object
#  6   user_id         72331 non-null  object
#  7   city            39278 non-null  object
#  8   county          37758 non-null  object
#  9   state           62966 non-null  object
#  10  country         72331 non-null  object
#  11  latitude        72331 non-null  float64
#  12  longitude       72331 non-null  float64
#  13  reply_count     72331 non-null  int64
#  14  quote_count     72331 non-null  int64
#  15  likes_count     72331 non-null  int64
#  16  retweet_counts  72331 non-null  int64
#  17  hyperlink       72331 non-null  object
# dtypes: float64(2), int64(4), object(12)
# memory usage: 10.5+ MB

# %%
# Create 'date_created' column with datetime conversion of 'date' column values
tweet_df['date_created'] = tweet_df['date'].apply(lambda x: datetime.strftime(datetime.strptime(x, '%a %b %d %H:%M:%S +0000 %Y'), '%Y-%m-%d %H:%M:%S'))

tweet_df.loc[:, ['date', 'date_created']]
# Out:
#                                  date         date_created
# 0      Thu Nov 03 23:59:52 +0000 2022  2022-11-03 23:59:52
# 1      Thu Nov 03 23:59:36 +0000 2022  2022-11-03 23:59:36
# 2      Thu Nov 03 23:59:33 +0000 2022  2022-11-03 23:59:33
# 3      Thu Nov 03 23:59:06 +0000 2022  2022-11-03 23:59:06
# 4      Thu Nov 03 23:59:00 +0000 2022  2022-11-03 23:59:00
# ...                               ...                  ...
# 72987  Sun Nov 13 00:00:13 +0000 2022  2022-11-13 00:00:13
# 72988  Sun Nov 13 00:00:11 +0000 2022  2022-11-13 00:00:11
# 72989  Sun Nov 13 00:00:03 +0000 2022  2022-11-13 00:00:03
# 72990  Sun Nov 13 00:00:02 +0000 2022  2022-11-13 00:00:02
# 72991  Sun Nov 13 00:00:01 +0000 2022  2022-11-13 00:00:01
#
# [72331 rows x 2 columns]

# %%
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72331 entries, 0 to 72991
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        72331 non-null  object
#  1   date            72331 non-null  object
#  2   full_text       72331 non-null  object
#  3   tweet_type      72331 non-null  object
#  4   hashtags        10552 non-null  object
#  5   mentions        54574 non-null  object
#  6   user_id         72331 non-null  object
#  7   city            39278 non-null  object
#  8   county          37758 non-null  object
#  9   state           62966 non-null  object
#  10  country         72331 non-null  object
#  11  latitude        72331 non-null  float64
#  12  longitude       72331 non-null  float64
#  13  reply_count     72331 non-null  int64
#  14  quote_count     72331 non-null  int64
#  15  likes_count     72331 non-null  int64
#  16  retweet_counts  72331 non-null  int64
#  17  hyperlink       72331 non-null  object
#  18  date_created    72331 non-null  object
# dtypes: float64(2), int64(4), object(13)
# memory usage: 11.0+ MB

# %%
# Change order of columns by moving new 'date_created' column to 'date' column position and exclude 'date' column 
tweet_df = tweet_df.loc[:,['tweet_id', 'date_created', 'full_text', 'tweet_type', 'hashtags', 'mentions',
                'user_id', 'city', 'county', 'state', 'country', 'latitude',
                'longitude', 'reply_count', 'quote_count', 'likes_count',
                'retweet_counts', 'hyperlink']]

# %%
# Confirm changes to columns
tweet_df.head(10)
# Out:
#               tweet_id         date_created  \
# 0  1588320083335467009  2022-11-03 23:59:52
# 1  1588320019259469824  2022-11-03 23:59:36
# 2  1588320006840160256  2022-11-03 23:59:33
# 3  1588319891446272001  2022-11-03 23:59:06
# 4  1588319866385477632  2022-11-03 23:59:00
# 5  1588319827651104769  2022-11-03 23:58:51
# 6  1588319810181529602  2022-11-03 23:58:46
# 7  1588319807375433728  2022-11-03 23:58:46
# 8  1588319706343124992  2022-11-03 23:58:22
# 9  1588319697808019456  2022-11-03 23:58:20
#
#                                            full_text      tweet_type hashtags  \
# 0  @UnnecRoughness A is Levis. \nB is KJ Jefferso...     Reply Tweet     None
# 1  Republican candidate's kids are almost KILLED ...  Original Tweet     None
# 2  @Jupiter62214807 @cjstheman_611 @BMC_MacDaddy ...     Reply Tweet     None
# 3  @davidhogg111 It’s 2022, get new talking point...     Reply Tweet     None
# 4  Watch: Gunman opens fire on Imran Khan https:/...  Original Tweet     None
# 5  @Stormof69 @VoteYesOn114 I’m always amused tha...     Reply Tweet     None
# 6  @ColinCowherd @DrHoodieMaddog What about kids ...     Reply Tweet     None
# 7  @Unnoble_Savage @brianleeellis @michaeljknowle...     Reply Tweet     None
# 8  @RobSchneider Let’s keep the 2nd Amendment and...     Reply Tweet     None
# 9  @davidhogg111 How many times a year are guns u...     Reply Tweet     None
#
#                                             mentions              user_id  \
# 0                                  [@UnnecRoughness]            531999121
# 1                                               None  1586027897579802624
# 2  [@Jupiter62214807, @cjstheman_611, @BMC_MacDad...   783106891274596352
# 3                                    [@davidhogg111]  1511111650199412739
# 4                                               None            287297482
# 5                        [@Stormof69, @VoteYesOn114]            412772316
# 6                   [@ColinCowherd, @DrHoodieMaddog]            147647057
# 7  [@Unnoble_Savage, @brianleeellis, @michaeljkno...  1040679839747825664
# 8                                    [@RobSchneider]  1586158533149499392
# 9                                    [@davidhogg111]  1527469162838253568
#
#          city            county          state        country   latitude  \
# 0        None              None       Arkansas  United States  -92.50044
# 1        None              None           None  United States  -98.50000
# 2        None              None  West Virginia  United States  -80.50009
# 3        None              None       Michigan  United States  -85.50033
# 4        None              None           None  United States  -98.50000
# 5  Manchester   Hartford County    Connecticut  United States  -72.52148
# 6    Brooklyn      Kings County       New York  United States  -73.94958
# 7     Willits  Mendocino County     California  United States -123.35557
# 8    Monterey   Monterey County     California  United States -121.89468
# 9        None              None           None  United States  -98.50000
#
#    longitude  reply_count  quote_count  likes_count  retweet_counts  \
# 0   34.75037            0            0            6               0
# 1   39.76000            0            0            0               0
# 2   38.50038            0            0            1               0
# 3   44.25029            0            0            8               0
# 4   39.76000            0            0            0               0
# 5   41.77593            0            0            4               0
# 6   40.65010            0            0            0               0
# 7   39.40961            0            0            0               0
# 8   36.60024            0            0            0               0
# 9   39.76000            0            0            0               0
#
#                                            hyperlink
# 0  https://twitter.com/twitter/status/15883200833...
# 1  https://twitter.com/twitter/status/15883200192...
# 2  https://twitter.com/twitter/status/15883200068...
# 3  https://twitter.com/twitter/status/15883198914...
# 4  https://twitter.com/twitter/status/15883198663...
# 5  https://twitter.com/twitter/status/15883198276...
# 6  https://twitter.com/twitter/status/15883198101...
# 7  https://twitter.com/twitter/status/15883198073...
# 8  https://twitter.com/twitter/status/15883197063...
# 9  https://twitter.com/twitter/status/15883196978...

# %%
# Create dummy_sentiment column for mockup visualizations
tweet_df['dummy_sentiment'] = np.random.choice(['anti-gun', 'pro-gun', 'neutral'], size=len(tweet_df))

# Confirm dummy column creation
tweet_df.head(10)
# Out:
#               tweet_id         date_created  \
# 0  1588320083335467009  2022-11-03 23:59:52
# 1  1588320019259469824  2022-11-03 23:59:36
# 2  1588320006840160256  2022-11-03 23:59:33
# 3  1588319891446272001  2022-11-03 23:59:06
# 4  1588319866385477632  2022-11-03 23:59:00
# 5  1588319827651104769  2022-11-03 23:58:51
# 6  1588319810181529602  2022-11-03 23:58:46
# 7  1588319807375433728  2022-11-03 23:58:46
# 8  1588319706343124992  2022-11-03 23:58:22
# 9  1588319697808019456  2022-11-03 23:58:20
#
#                                            full_text      tweet_type hashtags  \
# 0  @UnnecRoughness A is Levis. \nB is KJ Jefferso...     Reply Tweet     None
# 1  Republican candidate's kids are almost KILLED ...  Original Tweet     None
# 2  @Jupiter62214807 @cjstheman_611 @BMC_MacDaddy ...     Reply Tweet     None
# 3  @davidhogg111 It’s 2022, get new talking point...     Reply Tweet     None
# 4  Watch: Gunman opens fire on Imran Khan https:/...  Original Tweet     None
# 5  @Stormof69 @VoteYesOn114 I’m always amused tha...     Reply Tweet     None
# 6  @ColinCowherd @DrHoodieMaddog What about kids ...     Reply Tweet     None
# 7  @Unnoble_Savage @brianleeellis @michaeljknowle...     Reply Tweet     None
# 8  @RobSchneider Let’s keep the 2nd Amendment and...     Reply Tweet     None
# 9  @davidhogg111 How many times a year are guns u...     Reply Tweet     None
#
#                                             mentions              user_id  \
# 0                                  [@UnnecRoughness]            531999121
# 1                                               None  1586027897579802624
# 2  [@Jupiter62214807, @cjstheman_611, @BMC_MacDad...   783106891274596352
# 3                                    [@davidhogg111]  1511111650199412739
# 4                                               None            287297482
# 5                        [@Stormof69, @VoteYesOn114]            412772316
# 6                   [@ColinCowherd, @DrHoodieMaddog]            147647057
# 7  [@Unnoble_Savage, @brianleeellis, @michaeljkno...  1040679839747825664
# 8                                    [@RobSchneider]  1586158533149499392
# 9                                    [@davidhogg111]  1527469162838253568
#
#          city            county          state        country   latitude  \
# 0        None              None       Arkansas  United States  -92.50044
# 1        None              None           None  United States  -98.50000
# 2        None              None  West Virginia  United States  -80.50009
# 3        None              None       Michigan  United States  -85.50033
# 4        None              None           None  United States  -98.50000
# 5  Manchester   Hartford County    Connecticut  United States  -72.52148
# 6    Brooklyn      Kings County       New York  United States  -73.94958
# 7     Willits  Mendocino County     California  United States -123.35557
# 8    Monterey   Monterey County     California  United States -121.89468
# 9        None              None           None  United States  -98.50000
#
#    longitude  reply_count  quote_count  likes_count  retweet_counts  \
# 0   34.75037            0            0            6               0
# 1   39.76000            0            0            0               0
# 2   38.50038            0            0            1               0
# 3   44.25029            0            0            8               0
# 4   39.76000            0            0            0               0
# 5   41.77593            0            0            4               0
# 6   40.65010            0            0            0               0
# 7   39.40961            0            0            0               0
# 8   36.60024            0            0            0               0
# 9   39.76000            0            0            0               0
#
#                                            hyperlink dummy_sentiment
# 0  https://twitter.com/twitter/status/15883200833...        anti-gun
# 1  https://twitter.com/twitter/status/15883200192...         pro-gun
# 2  https://twitter.com/twitter/status/15883200068...         neutral
# 3  https://twitter.com/twitter/status/15883198914...        anti-gun
# 4  https://twitter.com/twitter/status/15883198663...         pro-gun
# 5  https://twitter.com/twitter/status/15883198276...         neutral
# 6  https://twitter.com/twitter/status/15883198101...         pro-gun
# 7  https://twitter.com/twitter/status/15883198073...        anti-gun
# 8  https://twitter.com/twitter/status/15883197063...         neutral
# 9  https://twitter.com/twitter/status/15883196978...         pro-gun

# %%
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72331 entries, 0 to 72991
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweet_id         72331 non-null  object
#  1   date_created     72331 non-null  object
#  2   full_text        72331 non-null  object
#  3   tweet_type       72331 non-null  object
#  4   hashtags         10552 non-null  object
#  5   mentions         54574 non-null  object
#  6   user_id          72331 non-null  object
#  7   city             39278 non-null  object
#  8   county           37758 non-null  object
#  9   state            62966 non-null  object
#  10  country          72331 non-null  object
#  11  latitude         72331 non-null  float64
#  12  longitude        72331 non-null  float64
#  13  reply_count      72331 non-null  int64
#  14  quote_count      72331 non-null  int64
#  15  likes_count      72331 non-null  int64
#  16  retweet_counts   72331 non-null  int64
#  17  hyperlink        72331 non-null  object
#  18  dummy_sentiment  72331 non-null  object
# dtypes: float64(2), int64(4), object(13)
# memory usage: 11.0+ MB

# %%
# Check random distribuiton of dummy_sentiment values
tweet_df['dummy_sentiment'].value_counts()
# Out:
# pro-gun     24256
# anti-gun    24070
# neutral     24005
# Name: dummy_sentiment, dtype: int64

# %%
# Set up AddFIPS API
af = addfips.AddFIPS()

# Add State FIPS codes to tweet_df
tweet_df['fips_state'] = tweet_df['state'].apply(lambda x: af.get_state_fips(x))

tweet_df.loc[:, ['state', 'fips_state']]
# Out:
#                   state fips_state
# 0              Arkansas         05
# 1                  None       None
# 2         West Virginia         54
# 3              Michigan         26
# 4                  None       None
# ...                 ...        ...
# 72987          Missouri         29
# 72988          New York         36
# 72989              Ohio         39
# 72990           Georgia         13
# 72991  Washington, D.C.       None
#
# [72331 rows x 2 columns]

# %%
# See which non-null states did not return a fips
tweet_df.loc[tweet_df['fips_state'].isna()][['state']].dropna().value_counts()
# Out:
# state
# Washington, D.C.    2148
# dtype: int64

# %%
# Confirm alternate naming yields fips from API for "Washington, D.C."
af.get_state_fips('D.C.')
# Out:
# '11'

# %%
# Save D.C. fips to variable
DC = af.get_state_fips('D.C.')

# Replace null value fips for "Washington, D.C." with the corresponding state fips code ("11")
tweet_df.loc[tweet_df['state'] == 'Washington, D.C.', 'fips_state'] = DC

# Confirm all necessary changes were made
tweet_df.loc[tweet_df['state'] == 'Washington, D.C.'][['fips_state']].value_counts()
# Out:
# fips_state
# 11            2148
# dtype: int64

# %%
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72331 entries, 0 to 72991
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweet_id         72331 non-null  object
#  1   date_created     72331 non-null  object
#  2   full_text        72331 non-null  object
#  3   tweet_type       72331 non-null  object
#  4   hashtags         10552 non-null  object
#  5   mentions         54574 non-null  object
#  6   user_id          72331 non-null  object
#  7   city             39278 non-null  object
#  8   county           37758 non-null  object
#  9   state            62966 non-null  object
#  10  country          72331 non-null  object
#  11  latitude         72331 non-null  float64
#  12  longitude        72331 non-null  float64
#  13  reply_count      72331 non-null  int64
#  14  quote_count      72331 non-null  int64
#  15  likes_count      72331 non-null  int64
#  16  retweet_counts   72331 non-null  int64
#  17  hyperlink        72331 non-null  object
#  18  dummy_sentiment  72331 non-null  object
#  19  fips_state       62966 non-null  object
# dtypes: float64(2), int64(4), object(14)
# memory usage: 11.6+ MB

# %%
# Add County FIPS codes to tweet_df
tweet_df['fips_county'] = tweet_df.apply(lambda x: af.get_county_fips(x['county'], state=x['state']) if x['county'] is not None else None, axis=1)

tweet_df.loc[:, ['county', 'fips_county']]
# Out:
#                 county fips_county
# 0                 None        None
# 1                 None        None
# 2                 None        None
# 3                 None        None
# 4                 None        None
# ...                ...         ...
# 72987   Webster County       29225
# 72988             None        None
# 72989  Hamilton County       39061
# 72990    Fulton County       13121
# 72991             None        None
#
# [72331 rows x 2 columns]

# %%
# Check if any non-null counties did not return a fips
tweet_df.loc[tweet_df['fips_county'].isna()][['county']].dropna().value_counts()
# Out:
# county
# City of Saint Louis         299
# City of Baltimore           214
# City of Fairfax             140
# City of Virginia Beach      115
# City of Richmond             90
# City of Roanoke              80
# City of Charlottesville      33
# City of Alexandria           30
# City of Fredericksburg       19
# City of Norfolk              18
# City of Chesapeake           12
# City of Lynchburg            11
# City of Newport News         10
# City of Williamsburg          7
# City of Winchester            6
# City of Hampton               6
# City of Suffolk               6
# City of Manassas              6
# City of Harrisonburg          4
# City of Salem                 3
# City of Falls Church          3
# City of Emporia               3
# City of Portsmouth            2
# City of Martinsville          2
# City of Lexington             2
# City of Danville              1
# City of Covington             1
# City of Colonial Heights      1
# City of Bristol               1
# City of Bedford               1
# City of Waynesboro            1
# City of Radford               1
# dtype: int64

# %%
# Confirm there is only 299 'City of Saint Louis' for testing example
tweet_df.loc[tweet_df['county'] == 'City of Saint Louis']['county'].value_counts()
# Out:
# City of Saint Louis    299
# Name: county, dtype: int64

# %%
# Replace "City of " with empy string to remove the naming convention from 'county' column
tweet_df['county'] = tweet_df['county'].apply(lambda x: x.replace("City of ", "") if x is not None else None)

# Confirm results against prior example
tweet_df.loc[tweet_df['county'] == 'Saint Louis']['county']
# Out:
# 105      Saint Louis
# 777      Saint Louis
# 793      Saint Louis
# 963      Saint Louis
# 1242     Saint Louis
#             ...
# 71460    Saint Louis
# 71478    Saint Louis
# 71825    Saint Louis
# 72682    Saint Louis
# 72955    Saint Louis
# Name: county, Length: 299, dtype: object

# %%
# Re-run code for getting county fips codes after cleaning county names with "City of "
tweet_df['fips_county'] = tweet_df.apply(lambda x: af.get_county_fips(x['county'], state=x['state']) if x['county'] is not None else None, axis=1)

tweet_df.loc[:, ['county', 'fips_county']]
# Out:
#                 county fips_county
# 0                 None        None
# 1                 None        None
# 2                 None        None
# 3                 None        None
# 4                 None        None
# ...                ...         ...
# 72987   Webster County       29225
# 72988             None        None
# 72989  Hamilton County       39061
# 72990    Fulton County       13121
# 72991             None        None
#
# [72331 rows x 2 columns]

# %%
# Check if any non-null counties did not return a fips
tweet_df.loc[tweet_df['fips_county'].isna()][['county']].dropna().value_counts()
# Out:
# Series([], dtype: int64)

# %%
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72331 entries, 0 to 72991
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweet_id         72331 non-null  object
#  1   date_created     72331 non-null  object
#  2   full_text        72331 non-null  object
#  3   tweet_type       72331 non-null  object
#  4   hashtags         10552 non-null  object
#  5   mentions         54574 non-null  object
#  6   user_id          72331 non-null  object
#  7   city             39278 non-null  object
#  8   county           37758 non-null  object
#  9   state            62966 non-null  object
#  10  country          72331 non-null  object
#  11  latitude         72331 non-null  float64
#  12  longitude        72331 non-null  float64
#  13  reply_count      72331 non-null  int64
#  14  quote_count      72331 non-null  int64
#  15  likes_count      72331 non-null  int64
#  16  retweet_counts   72331 non-null  int64
#  17  hyperlink        72331 non-null  object
#  18  dummy_sentiment  72331 non-null  object
#  19  fips_state       62966 non-null  object
#  20  fips_county      37758 non-null  object
# dtypes: float64(2), int64(4), object(15)
# memory usage: 12.1+ MB

# %%
# Change order of columns by moving 'fips_county' and 'fips_state' columns 
tweet_df = tweet_df.loc[:,['tweet_id', 'date_created', 'full_text', 'tweet_type', 'hashtags', 'mentions',
                'user_id', 'city', 'county', 'fips_county', 'state', 'fips_state', 'country', 'latitude',
                'longitude', 'reply_count', 'quote_count', 'likes_count',
                'retweet_counts', 'hyperlink', 'dummy_sentiment']]

# %%
# Final check of dataframe columns, non-null value counts and dtypes
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72331 entries, 0 to 72991
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweet_id         72331 non-null  object
#  1   date_created     72331 non-null  object
#  2   full_text        72331 non-null  object
#  3   tweet_type       72331 non-null  object
#  4   hashtags         10552 non-null  object
#  5   mentions         54574 non-null  object
#  6   user_id          72331 non-null  object
#  7   city             39278 non-null  object
#  8   county           37758 non-null  object
#  9   fips_county      37758 non-null  object
#  10  state            62966 non-null  object
#  11  fips_state       62966 non-null  object
#  12  country          72331 non-null  object
#  13  latitude         72331 non-null  float64
#  14  longitude        72331 non-null  float64
#  15  reply_count      72331 non-null  int64
#  16  quote_count      72331 non-null  int64
#  17  likes_count      72331 non-null  int64
#  18  retweet_counts   72331 non-null  int64
#  19  hyperlink        72331 non-null  object
#  20  dummy_sentiment  72331 non-null  object
# dtypes: float64(2), int64(4), object(15)
# memory usage: 12.1+ MB

# %%
# Confirm final dataframe
tweet_df.head(10)
# Out:
#               tweet_id         date_created  \
# 0  1588320083335467009  2022-11-03 23:59:52
# 1  1588320019259469824  2022-11-03 23:59:36
# 2  1588320006840160256  2022-11-03 23:59:33
# 3  1588319891446272001  2022-11-03 23:59:06
# 4  1588319866385477632  2022-11-03 23:59:00
# 5  1588319827651104769  2022-11-03 23:58:51
# 6  1588319810181529602  2022-11-03 23:58:46
# 7  1588319807375433728  2022-11-03 23:58:46
# 8  1588319706343124992  2022-11-03 23:58:22
# 9  1588319697808019456  2022-11-03 23:58:20
#
#                                            full_text      tweet_type hashtags  \
# 0  @UnnecRoughness A is Levis. \nB is KJ Jefferso...     Reply Tweet     None
# 1  Republican candidate's kids are almost KILLED ...  Original Tweet     None
# 2  @Jupiter62214807 @cjstheman_611 @BMC_MacDaddy ...     Reply Tweet     None
# 3  @davidhogg111 It’s 2022, get new talking point...     Reply Tweet     None
# 4  Watch: Gunman opens fire on Imran Khan https:/...  Original Tweet     None
# 5  @Stormof69 @VoteYesOn114 I’m always amused tha...     Reply Tweet     None
# 6  @ColinCowherd @DrHoodieMaddog What about kids ...     Reply Tweet     None
# 7  @Unnoble_Savage @brianleeellis @michaeljknowle...     Reply Tweet     None
# 8  @RobSchneider Let’s keep the 2nd Amendment and...     Reply Tweet     None
# 9  @davidhogg111 How many times a year are guns u...     Reply Tweet     None
#
#                                             mentions              user_id  \
# 0                                  [@UnnecRoughness]            531999121
# 1                                               None  1586027897579802624
# 2  [@Jupiter62214807, @cjstheman_611, @BMC_MacDad...   783106891274596352
# 3                                    [@davidhogg111]  1511111650199412739
# 4                                               None            287297482
# 5                        [@Stormof69, @VoteYesOn114]            412772316
# 6                   [@ColinCowherd, @DrHoodieMaddog]            147647057
# 7  [@Unnoble_Savage, @brianleeellis, @michaeljkno...  1040679839747825664
# 8                                    [@RobSchneider]  1586158533149499392
# 9                                    [@davidhogg111]  1527469162838253568
#
#          city            county fips_county  ... fips_state        country  \
# 0        None              None        None  ...         05  United States
# 1        None              None        None  ...       None  United States
# 2        None              None        None  ...         54  United States
# 3        None              None        None  ...         26  United States
# 4        None              None        None  ...       None  United States
# 5  Manchester   Hartford County       09003  ...         09  United States
# 6    Brooklyn      Kings County       36047  ...         36  United States
# 7     Willits  Mendocino County       06045  ...         06  United States
# 8    Monterey   Monterey County       06053  ...         06  United States
# 9        None              None        None  ...       None  United States
#
#     latitude  longitude  reply_count  quote_count  likes_count  \
# 0  -92.50044   34.75037            0            0            6
# 1  -98.50000   39.76000            0            0            0
# 2  -80.50009   38.50038            0            0            1
# 3  -85.50033   44.25029            0            0            8
# 4  -98.50000   39.76000            0            0            0
# 5  -72.52148   41.77593            0            0            4
# 6  -73.94958   40.65010            0            0            0
# 7 -123.35557   39.40961            0            0            0
# 8 -121.89468   36.60024            0            0            0
# 9  -98.50000   39.76000            0            0            0
#
#    retweet_counts                                          hyperlink  \
# 0               0  https://twitter.com/twitter/status/15883200833...
# 1               0  https://twitter.com/twitter/status/15883200192...
# 2               0  https://twitter.com/twitter/status/15883200068...
# 3               0  https://twitter.com/twitter/status/15883198914...
# 4               0  https://twitter.com/twitter/status/15883198663...
# 5               0  https://twitter.com/twitter/status/15883198276...
# 6               0  https://twitter.com/twitter/status/15883198101...
# 7               0  https://twitter.com/twitter/status/15883198073...
# 8               0  https://twitter.com/twitter/status/15883197063...
# 9               0  https://twitter.com/twitter/status/15883196978...
#
#   dummy_sentiment
# 0        anti-gun
# 1         pro-gun
# 2         neutral
# 3        anti-gun
# 4         pro-gun
# 5         neutral
# 6         pro-gun
# 7        anti-gun
# 8         neutral
# 9         pro-gun
#
# [10 rows x 21 columns]

# %%
# Export tweet_df as training data CSV
tweet_df.to_csv('../res/big_data_tweets.csv', index=False)
