# %% [markdown]
# # Fetching Tweets for Big Dataset (100K+ Tweets) from Twitter API

# %% [markdown]
# ## Twitter API Premium v1.1: Search Tweets 30-Day Endpoint

# %%
# Import dependencies
import tweepy
import pandas as pd
import numpy as np
import json

# %%
# Import API client token
import os
from dotenv import load_dotenv
load_dotenv()

twit_token = os.getenv('twit_token')

# %%
# Set up API authorization
auth = tweepy.OAuth2BearerHandler(twit_token)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
# Code reproduced from Twitter developer API documentation. Additional parsing features and customizations made where necessary for desired output.
def determine_tweet_type(tweet):
    # Check for reply indicator first
    if tweet["in_reply_to_status_id"] is not None:
        tweet_type = "Reply Tweet"
    # Check boolean quote status field but make sure it's not a Retweet (of a Quote Tweet) 
    elif tweet["is_quote_status"] is True and not tweet["text"].startswith("RT"):
        tweet_type = "Quote Tweet"
    # Check both indicators of a Retweet
    elif tweet["text"].startswith("RT") and tweet.get("retweeted_status") is not None:
        tweet_type = "Retweet"
    else:
        tweet_type = "Original Tweet"
    return tweet_type

parsedTweets = []
rawTweets = []

def parse_tweets(status):
    for tweet in status:
        
        rawTweets.append(tweet._json)
        hashtags = []
        mentions = []
        

        if 'extended_tweet' in tweet._json:
            full_text = tweet._json['extended_tweet']['full_text']

            # Collect hashtags from tweet into list
            hashtags_entity = tweet._json["extended_tweet"]["entities"]["hashtags"]
            if len(hashtags_entity) == 0:
                hashtags = None
            else:
                for hashtag in hashtags_entity:
                    hashtags.append("#" + hashtag['text'])

            # Collect mentions from tweet into list
            mentions_entity = tweet._json["extended_tweet"]["entities"]["user_mentions"]
            if len(mentions_entity) == 0:
                mentions = None
            else:
                for mention in mentions_entity:
                    mentions.append("@" + mention["screen_name"])

        else:
            full_text = tweet._json['text']

            # Collect hashtags from tweet into list
            hashtags_entity = tweet._json["entities"]["hashtags"]
            if len(hashtags_entity) == 0:
                hashtags = None
            else:
                for hashtag in hashtags_entity:
                    hashtags.append("#" + hashtag['text'])

            # Collect mentions from tweet into list
            mentions_entity = tweet._json["entities"]["user_mentions"]
            if len(mentions_entity) == 0:
                mentions = None
            else:
                for mention in mentions_entity:
                    mentions.append("@" + mention["screen_name"])
        
                
        # Get coordinates latitude and longitude into separate variables by subscripting coordinates if coordinates object not Nonetype
        coordinates = tweet._json["coordinates"]
        if coordinates is not None:
            coord_lat = tweet._json["coordinates"]["coordinates"][0]
            coord_lng = tweet._json["coordinates"]["coordinates"][1]
        else:
            coord_lat = None
            coord_lng = None
            
        
        # Get place attributes into separate variables by subscripting place if place object not Nonetype 
        place = tweet._json["place"]
        if place is not None:
            place_type = tweet._json["place"]["place_type"]
            place_name = tweet._json["place"]["name"]
            place_full_name = tweet._json["place"]["full_name"]
            country_code = tweet._json["place"]["country_code"]
            country = tweet._json["place"]["country"]
        else:
            place_type = None
            place_name = None
            place_full_name = None
            country_code = None
            country = None
            
        # Parsing profile geo data

        # First intialize profile geo field values as Nonetype for the default value (value if field not found in profile geo data)
        prof_country = None
        prof_country_code = None
        prof_locality = None
        prof_region = None
        prof_sub_region = None
        prof_full_name = None
        prof_coord_lat = None
        prof_coord_lng = None 

        # Parse desired profile geo data if the field is present 
        for field in tweet._json["user"]: 
            if field == "derived":
                prof_geo_data = tweet._json["user"]["derived"]
                if prof_geo_data["locations"] is not None:
                    for field in prof_geo_data["locations"][0]:
                        if field == "country":
                            prof_country = prof_geo_data["locations"][0][field]

                        elif field == "country_code":
                            prof_country_code = prof_geo_data["locations"][0][field]

                        elif field == "locality":
                            prof_locality = prof_geo_data["locations"][0][field]

                        elif field == "region":
                            prof_region = prof_geo_data["locations"][0][field]

                        elif field == "sub_region":
                            prof_sub_region = prof_geo_data["locations"][0][field]

                        elif field == "full_name":
                            prof_full_name = prof_geo_data["locations"][0][field]

                        elif field == "geo":
                            prof_coord_lat = prof_geo_data["locations"][0][field]["coordinates"][0]
                            prof_coord_lng = prof_geo_data["locations"][0][field]["coordinates"][1]

                        else:
                            pass
                else:
                    pass
            else:
                pass
            

            
        # Create dict with key-value pairs of parsed field and corresponding data
        mydict = { "tweet_id": tweet._json["id_str"], #Tweet ID
                       "date":tweet._json["created_at"], #Timestamp of tweet creation
                       "full_text": full_text, #Full tweet text
                       "tweet_type": determine_tweet_type(tweet._json), #Type of tweet
                       "hashtags": hashtags, #List of hashtags used in the tweet
                       "mentions": mentions, #List of mentions used in the tweet
                       "user_id": tweet._json["user"]["id_str"], #Twitter user profile ID
                       "user_location": tweet._json["user"]["location"], #The user's listed location
                       "geo": tweet._json["geo"], #Geodata 'geo' attribute
                       "lat_coordinates": coord_lat, #Geodata 'latitude coordinates' from 'coordinates' attribute
                       "lng_coordinates": coord_lng, #Geodata 'longitude coordinates' from 'coordinates' attribute
                       "place_type": place_type, #Geodata 'place_type' from 'place' attribute
                       "place_name": place_name, #Geodata 'name' from 'place' attribute
                       "place_full_name": place_full_name, #Geodata 'full_name' from 'place' attribute
                       "country_code": country_code, #Geodata 'country_code' from 'place' attribute
                       "country": country, #Geodata 'country' from 'place' attribute
                       "prof_country": prof_country, #Profile geodata 'country' from 'user''derived''locations'
                       "prof_country_code": prof_country_code, #Profile geodata 'country_code' from 'user''derived''locations'
                       "prof_locality": prof_locality, #Profile geodata 'locality' from 'user''derived''locations'
                       "prof_region": prof_region, #Profile geodata 'region' from 'user''derived''locations'
                       "prof_sub_region": prof_sub_region, #Profile geodata 'sub_region' from 'user''derived''locations'
                       "prof_full_name": prof_full_name, #Profile geodata 'full_name' from 'user''derived''locations'
                       "prof_coord_lat": prof_coord_lat, #Profile geodata 'latitude' from 'user''derived''locations''geo''coordinates'
                       "prof_coord_lng": prof_coord_lng, #Profile geodata 'longitude' from 'user''derived''locations''geo''coordinates'
                       "reply_count": tweet._json["reply_count"], #Number of times Tweet has been replied to
                       "quote_count": tweet._json["quote_count"], # Number of times Tweet has been quoted
                       "likes_count": tweet._json["favorite_count"], #Number of times Tweet has been liked 
                       "retweet_counts": tweet._json["retweet_count"], #Number of times this Tweet has been retweeted
                       "hyperlink": "https://twitter.com/twitter/status/" + tweet._json["id_str"] #Link to tweet
              }
        
        # Append parsed tweet data to list
        parsedTweets.append(mydict) # Add Tweet to parsedTweets list

# %%
# Code to run query against the Twitter API v1.1 Premium - 30 day search endpoint for fetching tweets in the last 30-day archive 

query = '(#guncontrol OR #gunrights OR #gunsense OR #2a OR #gunviolence OR #nra OR #guns OR #shooting OR #firearms OR #gunsafety OR #uvalde \
OR "gun control" OR "2nd amendment" OR ("gun" "violence") OR "right to bear" OR "nra" OR ("gun" "safety") OR ("gun" "rights") \
OR "good guy with a gun" OR "assault weapons" OR ("ban" "guns") OR "ban assault" OR ("school" "shootings") OR "ar-15" OR "mass shootings" \
OR "open carry" OR "gun owners" OR "concealed carry" OR "gun laws" OR "gun law" OR "pro-gun" OR "anti-gun" OR "gun safety" OR "high capacity magazine" \
OR "second amendment" OR "gun lobby" OR "gun ownership" OR "carry permit" OR "bump stock" OR "gunman" OR "red flag laws" OR "red-flag laws" OR "brady law" \
OR "gun sales" OR ("buying" ("gun" OR "guns")) OR "gun shows" OR "gun sense" OR "sandy hook" OR ("guns" ("republicans" OR "democrats")) OR (("background check" OR "background checks") \
("gun" OR "guns" OR "sale" OR "sales")) OR (("legal" OR "illegal") ("gun" OR "guns"))) lang:en profile_country:US -is:retweet -is:quote'


# Initalize lists to populate with raw and parsed using parsing function
rawTweets = []
parsedTweets = []
from_date = 1103
to_date = 1104
date_range = range(10)

# Fetch tweets from the endpoint using pagination to collect up to 18,500 tweets for each specified day (UTC)
for date in date_range:
    status = tweepy.Cursor(api.search_30_day, label='gunsentiment', query=query, fromDate=f'2022{from_date}0000', toDate=f'2022{to_date}0000', maxResults='500').items(14000)

    # parse the fetched tweet and store key-value pairs in list of dictionaries in parsedTweets. Append raw JSON responses to rawTweets list
    parse_tweets(status)
    
    from_date += 1
    to_date += 1

# convert raw tweets JSON responses array into .json file
with open("../res/big_data_tweets_raw.json", "w") as training_tweets:
    json.dump(rawTweets, training_tweets)
    
    
tweet_df = pd.DataFrame(parsedTweets)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# Cell In [43], line 24
#      21 status = tweepy.Cursor(api.search_30_day, label='gunsentiment', query=query, fromDate=f'2022{from_date}0000', toDate=f'2022{to_date}0000', maxResults='500').items(17000)
#      23 # parse the fetched tweet and store key-value pairs in list of dictionaries in parsedTweets. Append raw JSON responses to rawTweets list
# ---> 24 parse_tweets(status)
#      26 from_date += 1
#      27 to_date += 1
#
# Cell In [42], line 20, in parse_tweets(status)
#      19 def parse_tweets(status):
# ---> 20     for tweet in status:
#      22         rawTweets.append(tweet._json)
#      23         hashtags = []
#
# File ~/miniforge3/envs/tf_env/lib/python3.9/site-packages/tweepy/cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~/miniforge3/envs/tf_env/lib/python3.9/site-packages/tweepy/cursor.py:286, in ItemIterator.next(self)
#     283     raise StopIteration
#     284 if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285     # Reached end of current page, get the next page...
# --> 286     self.current_page = next(self.page_iterator)
#     287     while len(self.current_page) == 0:
#     288         self.current_page = next(self.page_iterator)
#
# File ~/miniforge3/envs/tf_env/lib/python3.9/site-packages/tweepy/cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~/miniforge3/envs/tf_env/lib/python3.9/site-packages/tweepy/cursor.py:260, in NextIterator.next(self)
#     258 if self.next_token == -1 or self.page_count >= self.limit:
#     259     raise StopIteration
# --> 260 data = self.method(next=self.next_token, return_cursors=True, *self.args, **self.kwargs)
#     261 self.page_count += 1
#     262 if isinstance(data, tuple):
#
# File ~/miniforge3/envs/tf_env/lib/python3.9/site-packages/tweepy/api.py:33, in pagination.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      31 @functools.wraps(method)
#      32 def wrapper(*args, **kwargs):
# ---> 33     return method(*args, **kwargs)
#
# File ~/miniforge3/envs/tf_env/lib/python3.9/site-packages/tweepy/api.py:46, in payload.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      44 kwargs['payload_list'] = payload_list
#      45 kwargs['payload_type'] = payload_type
# ---> 46 return method(*args, **kwargs)
#
# File ~/miniforge3/envs/tf_env/lib/python3.9/site-packages/tweepy/api.py:369, in API.search_30_day(self, label, query, **kwargs)
#     292 @pagination(mode='next')
#     293 @payload('status', list=True)
#     294 def search_30_day(self, label, query, **kwargs):
#     295     """search_30_day(label, query, *, tag, fromDate, toDate, maxResults, \
#     296                      next)
#     297
#    (...)
#     367     https://developer.twitter.com/en/docs/twitter-api/premium/search-api/api-reference/premium-search
#     368     """
# --> 369     return self.request(
#     370         'GET', f'tweets/search/30day/{label}', endpoint_parameters=(
#     371             'query', 'tag', 'fromDate', 'toDate', 'maxResults', 'next'
#     372         ), query=query, **kwargs
#     373     )
#
# File ~/miniforge3/envs/tf_env/lib/python3.9/site-packages/tweepy/api.py:269, in API.request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     267     raise NotFound(resp)
#     268 if resp.status_code == 429:
# --> 269     raise TooManyRequests(resp)
#     270 if resp.status_code >= 500:
#     271     raise TwitterServerError(resp)
#
# TooManyRequests: 429 Too Many Requests
# Exceeded rate limit

# %%
rawTweets[14836]
# Out:
# {'created_at': 'Fri Nov 04 00:00:02 +0000 2022',
#  'id': 1588320126427836417,
#  'id_str': '1588320126427836417',
#  'text': 'If you keep a handgun in your glove box as most any Tennessean may legally do, it should always occur to you to loc… https://t.co/aTxteyAK9j',
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'truncated': True,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 23782016,
#   'id_str': '23782016',
#   'name': 'Times-News Online',
#   'screen_name': 'timesnewsonline',
#   'location': 'Kingsport, TN',
#   'url': 'http://www.timesnews.net',
#   'description': 'Breaking news and information for Kingsport, TN\n\nLinktree: https://linktr.ee/kingsport_times_news',
#   'translator_type': 'none',
#   'derived': {'locations': [{'country': 'United States',
#      'country_code': 'US',
#      'locality': 'Kingsport',
#      'region': 'Tennessee',
#      'sub_region': 'Sullivan County',
#      'full_name': 'Kingsport, Tennessee, United States',
#      'geo': {'coordinates': [-82.56182, 36.54843], 'type': 'point'}}]},
#   'protected': False,
#   'verified': False,
#   'followers_count': 11565,
#   'friends_count': 132,
#   'listed_count': 223,
#   'favourites_count': 720,
#   'statuses_count': 75805,
#   'created_at': 'Wed Mar 11 15:57:33 +0000 2009',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': '000105',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_tile': False,
#   'profile_link_color': '2FC2EF',
#   'profile_sidebar_border_color': '181A1E',
#   'profile_sidebar_fill_color': '252429',
#   'profile_text_color': '666666',
#   'profile_use_background_image': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/968564781488791553/soapPryW_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/968564781488791553/soapPryW_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/23782016/1627573680',
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None,
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'extended_tweet': {'full_text': 'If you keep a handgun in your glove box as most any Tennessean may legally do, it should always occur to you to lock your vehicle whenever you’re not in it.\n\n#editorial #ironpipeline #guns \n\nhttps://t.co/0FhakjcBxr',
#   'display_text_range': [0, 214],
#   'entities': {'hashtags': [{'text': 'editorial', 'indices': [158, 168]},
#     {'text': 'ironpipeline', 'indices': [169, 182]},
#     {'text': 'guns', 'indices': [183, 188]}],
#    'urls': [{'url': 'https://t.co/0FhakjcBxr',
#      'expanded_url': 'https://www.timesnews.net/opinion/editorials/editorial-lets-help-shut-down-the-iron-pipeline/article_cf097f18-5488-11ed-b209-8b4243b37f62.html',
#      'display_url': 'timesnews.net/opinion/editor…',
#      'unwound': {'url': 'https://www.timesnews.net/opinion/editorials/editorial-lets-help-shut-down-the-iron-pipeline/article_cf097f18-5488-11ed-b209-8b4243b37f62.html',
#       'status': 200,
#       'title': "Editorial: Let's help shut down the Iron Pipeline",
#       'description': 'Tennessee is among Southern states that provide thousands of stolen or illegal weapons to Northern states via the Iron Pipeline.'},
#      'indices': [191, 214]}],
#    'user_mentions': [],
#    'symbols': []}},
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'entities': {'hashtags': [],
#   'urls': [{'url': 'https://t.co/aTxteyAK9j',
#     'expanded_url': 'https://twitter.com/i/web/status/1588320126427836417',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}],
#   'user_mentions': [],
#   'symbols': []},
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'edit_history': {'initial_tweet_id': '1588320126427836417',
#   'edit_tweet_ids': ['1588320126427836417']},
#  'edit_controls': {'editable_until_ms': 1667521802000, 'edits_remaining': 5},
#  'editable': True,
#  'filter_level': 'low',
#  'lang': 'en',
#  'matching_rules': [{'tag': None}]}

# %%
len(parsedTweets)
# Out:
# 28775

# %%
tweet
# Out:
# {'_json': {'created_at': 'Fri Nov 04 00:00:02 +0000 2022',
#   'id': 1588320126427836417,
#   'id_str': '1588320126427836417',
#   'text': 'If you keep a handgun in your glove box as most any Tennessean may legally do, it should always occur to you to loc… https://t.co/aTxteyAK9j',
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 23782016,
#    'id_str': '23782016',
#    'name': 'Times-News Online',
#    'screen_name': 'timesnewsonline',
#    'location': 'Kingsport, TN',
#    'url': 'http://www.timesnews.net',
#    'description': 'Breaking news and information for Kingsport, TN\n\nLinktree: https://linktr.ee/kingsport_times_news',
#    'translator_type': 'none',
#    'derived': {'locations': [{'country': 'United States',
#       'country_code': 'US',
#       'locality': 'Kingsport',
#       'region': 'Tennessee',
#       'sub_region': 'Sullivan County',
#       'full_name': 'Kingsport, Tennessee, United States',
#       'geo': {'coordinates': [-82.56182, 36.54843], 'type': 'point'}}]},
#    'protected': False,
#    'verified': False,
#    'followers_count': 11565,
#    'friends_count': 132,
#    'listed_count': 223,
#    'favourites_count': 720,
#    'statuses_count': 75805,
#    'created_at': 'Wed Mar 11 15:57:33 +0000 2009',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '000105',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_link_color': '2FC2EF',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/968564781488791553/soapPryW_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/968564781488791553/soapPryW_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/23782016/1627573680',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': 'If you keep a handgun in your glove box as most any Tennessean may legally do, it should always occur to you to lock your vehicle whenever you’re not in it.\n\n#editorial #ironpipeline #guns \n\nhttps://t.co/0FhakjcBxr',
#    'display_text_range': [0, 214],
#    'entities': {'hashtags': [{'text': 'editorial', 'indices': [158, 168]},
#      {'text': 'ironpipeline', 'indices': [169, 182]},
#      {'text': 'guns', 'indices': [183, 188]}],
#     'urls': [{'url': 'https://t.co/0FhakjcBxr',
#       'expanded_url': 'https://www.timesnews.net/opinion/editorials/editorial-lets-help-shut-down-the-iron-pipeline/article_cf097f18-5488-11ed-b209-8b4243b37f62.html',
#       'display_url': 'timesnews.net/opinion/editor…',
#       'unwound': {'url': 'https://www.timesnews.net/opinion/editorials/editorial-lets-help-shut-down-the-iron-pipeline/article_cf097f18-5488-11ed-b209-8b4243b37f62.html',
#        'status': 200,
#        'title': "Editorial: Let's help shut down the Iron Pipeline",
#        'description': 'Tennessee is among Southern states that provide thousands of stolen or illegal weapons to Northern states via the Iron Pipeline.'},
#       'indices': [191, 214]}],
#     'user_mentions': [],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/aTxteyAK9j',
#      'expanded_url': 'https://twitter.com/i/web/status/1588320126427836417',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'edit_history': {'initial_tweet_id': '1588320126427836417',
#    'edit_tweet_ids': ['1588320126427836417']},
#   'edit_controls': {'editable_until_ms': 1667521802000, 'edits_remaining': 5},
#   'editable': True,
#   'filter_level': 'low',
#   'lang': 'en',
#   'matching_rules': [{'tag': None}]}}

# %%
parse_tweets(status)

# %%
len(parsedTweets)
# Out:
# 10215

# %%
tweet_df = pd.DataFrame(parsedTweets)

# %%
tweet_df['date'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Thu Nov 03 23:59:52 +0000 2022
# 1        Thu Nov 03 23:59:36 +0000 2022
# 2        Thu Nov 03 23:59:33 +0000 2022
# 3        Thu Nov 03 23:59:06 +0000 2022
# 4        Thu Nov 03 23:59:00 +0000 2022
#                       ...
# 10210    Fri Nov 04 17:19:09 +0000 2022
# 10211    Fri Nov 04 17:19:07 +0000 2022
# 10212    Fri Nov 04 17:19:06 +0000 2022
# 10213    Fri Nov 04 17:19:03 +0000 2022
# 10214    Fri Nov 04 17:18:50 +0000 2022
# Name: date, Length: 10215, dtype: object>

# %%
# Check tweets dataframe data types and missing values for each column
tweet_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [11], line 2
#       1 # Check tweets dataframe data types and missing values for each column
# ----> 2 tweet_df.info()
#
# NameError: name 'tweet_df' is not defined

# %%
# drop 'geo', 'lat_coordinates', and 'lng_coordinates' columns for insufficient data
tweet_df.drop(['geo', 'lat_coordinates', 'lng_coordinates'], axis=1, inplace=True)
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8801 entries, 0 to 8800
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tweet_id           8801 non-null   object
#  1   date               8801 non-null   object
#  2   full_text          8801 non-null   object
#  3   tweet_type         8801 non-null   object
#  4   hashtags           1366 non-null   object
#  5   mentions           6147 non-null   object
#  6   user_location      8781 non-null   object
#  7   place_type         244 non-null    object
#  8   place_name         244 non-null    object
#  9   place_full_name    244 non-null    object
#  10  country_code       244 non-null    object
#  11  country            244 non-null    object
#  12  prof_country       8747 non-null   object
#  13  prof_country_code  8747 non-null   object
#  14  prof_locality      4645 non-null   object
#  15  prof_region        7680 non-null   object
#  16  prof_sub_region    4477 non-null   object
#  17  prof_full_name     8747 non-null   object
#  18  prof_coord_lat     8747 non-null   float64
#  19  prof_coord_lng     8747 non-null   float64
#  20  reply_count        8801 non-null   int64
#  21  quote_count        8801 non-null   int64
#  22  likes_count        8801 non-null   int64
#  23  retweet_counts     8801 non-null   int64
#  24  hyperlink          8801 non-null   object
# dtypes: float64(2), int64(4), object(19)
# memory usage: 1.7+ MB

# %%
# Check top 10 rows of tweets dataframe
tweet_df.head(10)
# Out:
#               tweet_id                            date  \
# 0  1587957708166426625  Wed Nov 02 23:59:55 +0000 2022
# 1  1587957661085171712  Wed Nov 02 23:59:43 +0000 2022
# 2  1587957440494141441  Wed Nov 02 23:58:51 +0000 2022
# 3  1587957427823349760  Wed Nov 02 23:58:48 +0000 2022
# 4  1587957397422841861  Wed Nov 02 23:58:41 +0000 2022
# 5  1587957395539611648  Wed Nov 02 23:58:40 +0000 2022
# 6  1587957387503501312  Wed Nov 02 23:58:38 +0000 2022
# 7  1587957369543204865  Wed Nov 02 23:58:34 +0000 2022
# 8  1587957359636189185  Wed Nov 02 23:58:32 +0000 2022
# 9  1587957220502822912  Wed Nov 02 23:57:58 +0000 2022
#
#                                            full_text      tweet_type hashtags  \
# 0  @PapiiDev_ @aaronbricks69 @Barstooldmv Man ppl...     Reply Tweet     None
# 1    @watertigernyc Hey, now that NYC is open carry…     Reply Tweet     None
# 2  .@KaneGovernment decides new gun law not ready...  Original Tweet     None
# 3  @thediva76 @iamjadebrieanne @brolys_maiden @un...     Reply Tweet     None
# 4  HipHop needs to go on strike! No more gun play...  Original Tweet     None
# 5  @bradlena1 @RadioFreeTom Republicans push for ...     Reply Tweet     None
# 6  Iowans, Strict scrutiny means the rights of th...  Original Tweet     None
# 7  The 2nd Amendment calls for a "A well regulate...  Original Tweet     None
# 8  @marla_vous @BetoORourke Abbott is Forever. So...     Reply Tweet     None
# 9  A Federal Judge Calls Clarence Thomas’ Bluff o...  Original Tweet     None
#
#                                             mentions     user_location  \
# 0         [@PapiiDev_, @aaronbricks69, @Barstooldmv]  Indianapolis, IN
# 1                                   [@watertigernyc]   New Jersey, USA
# 2                    [@KaneGovernment, @dailyherald]  Kane County, IL.
# 3  [@thediva76, @iamjadebrieanne, @brolys_maiden,...    Washington, DC
# 4                                               None      douglasville
# 5                        [@bradlena1, @RadioFreeTom]      Florida, USA
# 6                                               None      Johnston, IA
# 7                                               None           America
# 8                        [@marla_vous, @BetoORourke]   California, USA
# 9                                               None         Euclid,OH
#
#   place_type place_name place_full_name  ...       prof_region  \
# 0       None       None            None  ...           Indiana
# 1       None       None            None  ...        New Jersey
# 2       None       None            None  ...          Illinois
# 3       None       None            None  ...  Washington, D.C.
# 4       None       None            None  ...           Georgia
# 5       None       None            None  ...           Florida
# 6       None       None            None  ...              Iowa
# 7       None       None            None  ...              None
# 8       None       None            None  ...        California
# 9       None       None            None  ...              Ohio
#
#    prof_sub_region                        prof_full_name prof_coord_lat  \
# 0    Marion County  Indianapolis, Indiana, United States      -86.15804
# 1             None             New Jersey, United States      -74.49987
# 2    Greene County         Kane, Illinois, United States      -90.35373
# 3             None       Washington, D.C., United States      -77.00025
# 4   Douglas County  Douglasville, Georgia, United States      -84.74771
# 5             None                Florida, United States      -82.50010
# 6      Polk County         Johnston, Iowa, United States      -93.69772
# 7             None                         United States      -98.50000
# 8             None             California, United States     -119.75126
# 9  Cuyahoga County           Euclid, Ohio, United States      -81.52679
#
#   prof_coord_lng reply_count quote_count likes_count  retweet_counts  \
# 0       39.76838           1           0           0               0
# 1       40.16706           0           0           2               0
# 2       39.19005           0           0           0               0
# 3       38.91706           1           0           0               0
# 4       33.75150           0           0           0               0
# 5       28.75054           0           0          26               1
# 6       41.67304           0           0           0               0
# 7       39.76000           0           0           1               0
# 8       37.25022           0           0           0               0
# 9       41.59310           0           0           0               0
#
#                                            hyperlink
# 0  https://twitter.com/twitter/status/15879577081...
# 1  https://twitter.com/twitter/status/15879576610...
# 2  https://twitter.com/twitter/status/15879574404...
# 3  https://twitter.com/twitter/status/15879574278...
# 4  https://twitter.com/twitter/status/15879573974...
# 5  https://twitter.com/twitter/status/15879573955...
# 6  https://twitter.com/twitter/status/15879573875...
# 7  https://twitter.com/twitter/status/15879573695...
# 8  https://twitter.com/twitter/status/15879573596...
# 9  https://twitter.com/twitter/status/15879572205...
#
# [10 rows x 25 columns]

# %%
# Confirm results for user.location and profile geo data parsing
tweet_df.loc[:, ['user_location', 'prof_country', 'prof_country_code', 'prof_locality', 'prof_region', 'prof_sub_region', 'prof_full_name']].head(10)
# Out:
#       user_location   prof_country prof_country_code prof_locality  \
# 0  Indianapolis, IN  United States                US  Indianapolis
# 1   New Jersey, USA  United States                US          None
# 2  Kane County, IL.  United States                US          Kane
# 3    Washington, DC  United States                US          None
# 4      douglasville  United States                US  Douglasville
# 5      Florida, USA  United States                US          None
# 6      Johnston, IA  United States                US      Johnston
# 7           America  United States                US          None
# 8   California, USA  United States                US          None
# 9         Euclid,OH  United States                US        Euclid
#
#         prof_region  prof_sub_region                        prof_full_name
# 0           Indiana    Marion County  Indianapolis, Indiana, United States
# 1        New Jersey             None             New Jersey, United States
# 2          Illinois    Greene County         Kane, Illinois, United States
# 3  Washington, D.C.             None       Washington, D.C., United States
# 4           Georgia   Douglas County  Douglasville, Georgia, United States
# 5           Florida             None                Florida, United States
# 6              Iowa      Polk County         Johnston, Iowa, United States
# 7              None             None                         United States
# 8        California             None             California, United States
# 9              Ohio  Cuyahoga County           Euclid, Ohio, United States

# %%
# Check distribution of tweet types
tweet_df['tweet_type'].value_counts()
# Out:
# Reply Tweet       5788
# Original Tweet    3013
# Name: tweet_type, dtype: int64

# %%
# Check for unique values and respective counts in 'country_code' column
tweet_df['country_code'].value_counts()
# Out:
# US    241
# TZ      1
# GB      1
# CO      1
# Name: country_code, dtype: int64

# %%
# Check rows with non-null values in 'country_code' that are not 'US' for conflicts with profile geo data
tweet_df.loc[lambda df: (df['country_code'] == 'TZ') | (df['country_code'] == 'GB') | (df['country_code'] == 'CO')].T
# Out:
#                                                                 1495  \
# tweet_id                                         1587906553058828289
# date                                  Wed Nov 02 20:36:38 +0000 2022
# full_text          @ValaAfshar Yeah ikr but at least they don’t b...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions                                               [@ValaAfshar]
# user_location                               U.S Intelligence Outpost
# place_type                                                     admin
# place_name                                             Dar es Salaam
# place_full_name                              Dar es Salaam, Tanzania
# country_code                                                      TZ
# country                                                     Tanzania
# prof_country                                                    None
# prof_country_code                                               None
# prof_locality                                                   None
# prof_region                                                     None
# prof_sub_region                                                 None
# prof_full_name                                                  None
# prof_coord_lat                                                   NaN
# prof_coord_lng                                                   NaN
# reply_count                                                        0
# quote_count                                                        0
# likes_count                                                        0
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15879065530...
#
#                                                                 2650  \
# tweet_id                                         1587868633472049153
# date                                  Wed Nov 02 18:05:58 +0000 2022
# full_text          Every body deserves to feel perfect #shooting ...
# tweet_type                                            Original Tweet
# hashtags           [#shooting, #elegance, #classy, #elegant, #pho...
# mentions                                                        None
# user_location                                                 Devon
# place_type                                                      city
# place_name                                               Kilkhampton
# place_full_name                                 Kilkhampton, England
# country_code                                                      GB
# country                                               United Kingdom
# prof_country                                           United States
# prof_country_code                                                 US
# prof_locality                                                  Devon
# prof_region                                             Pennsylvania
# prof_sub_region                                       Chester County
# prof_full_name                    Devon, Pennsylvania, United States
# prof_coord_lat                                             -75.42908
# prof_coord_lng                                              40.04928
# reply_count                                                        0
# quote_count                                                        0
# likes_count                                                        1
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15878686334...
#
#                                                                 4146
# tweet_id                                         1587825249898450947
# date                                  Wed Nov 02 15:13:34 +0000 2022
# full_text          @robreiner Dana Loesch, spokeswoman NRA, recei...
# tweet_type                                               Reply Tweet
# hashtags                                                        None
# mentions                                                [@robreiner]
# user_location                                         Fort Worth, TX
# place_type                                                      city
# place_name                                              Bogotá, D.C.
# place_full_name                               Bogotá, D.C., Colombia
# country_code                                                      CO
# country                                                     Colombia
# prof_country                                           United States
# prof_country_code                                                 US
# prof_locality                                             Fort Worth
# prof_region                                                    Texas
# prof_sub_region                                       Tarrant County
# prof_full_name                      Fort Worth, Texas, United States
# prof_coord_lat                                             -97.32085
# prof_coord_lng                                              32.72541
# reply_count                                                        0
# quote_count                                                        0
# likes_count                                                        0
# retweet_counts                                                     0
# hyperlink          https://twitter.com/twitter/status/15878252498...

# %%
# Export tweet_df as training data CSV
tweet_df.to_csv('../res/big_data_tweets.csv', index=False)
